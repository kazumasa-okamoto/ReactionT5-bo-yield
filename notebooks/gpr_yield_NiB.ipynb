# %% [markdown]
# ## データセットの準備

# %%
import pandas as pd
import numpy as np
from rdkit import Chem
from rdkit.Chem import AllChem
import warnings
warnings.filterwarnings('ignore')

# %%
def space_clean(row):
    """空白文字を整理"""
    row = row.replace(". ", "").replace(" .", "").replace("  ", " ")
    return row

def canonicalize(smiles):
    """SMILESを正規化"""
    try:
        new_smiles = Chem.MolToSmiles(Chem.MolFromSmiles(smiles), canonical=True)
    except:
        new_smiles = None
    return new_smiles

# %%
# データ読み込み
df = pd.read_csv("../data/NiB/inchi_23l_reaction_t5_ready.csv")
print(f"データ数: {len(df)}")
df.head()
# Out:
# データ数: 1518
#                           REACTANT     REAGENT  \
# 0  CN(C)S(=O)(=O)Oc1ccc2[nH]ccc2c1  OB(O)B(O)O
# 1  CN(C)S(=O)(=O)Oc1ccc2[nH]ccc2c1  OB(O)B(O)O
# 2  CN(C)S(=O)(=O)Oc1ccc2[nH]ccc2c1  OB(O)B(O)O
# 3  CN(C)S(=O)(=O)Oc1ccc2[nH]ccc2c1  OB(O)B(O)O
# 4  CN(C)S(=O)(=O)Oc1ccc2[nH]ccc2c1  OB(O)B(O)O
#
#                                             CATALYST SOLVENT  \
# 0                 CN(C)c1ccc(P(c2ccccc2)c2ccccc2)cc1     CCO
# 1  CCCCC1([PH+](C2CCCCC2)C2CCCCC2)c2ccccc2-c2cccc...     CCO
# 2              c1ccc(-n2cccc2P(C2CCCCC2)C2CCCCC2)cc1     CCO
# 3  c1ccc(-c2nn(-c3ccccc3)c(-c3ccccc3)c2-n2nccc2P(...     CCO
# 4             c1ccc(-c2ccccc2P(C2CCCCC2)C2CCCCC2)cc1     CCO
#
#                  PRODUCT  YIELD
# 0  OB(O)c1ccc2[nH]ccc2c1  87.13
# 1  OB(O)c1ccc2[nH]ccc2c1   6.37
# 2  OB(O)c1ccc2[nH]ccc2c1  71.75
# 3  OB(O)c1ccc2[nH]ccc2c1  64.52
# 4  OB(O)c1ccc2[nH]ccc2c1  80.44

# %%
# 必須カラムの存在チェックと補完
required_cols = ["REACTANT", "CATALYST", "REAGENT", "SOLVENT", "PRODUCT"]
for col in required_cols:
    if col not in df.columns:
        df[col] = ""

# YIELDを標準化（0-1に正規化）
if "YIELD" in df.columns:
    df["YIELD"] = df["YIELD"].clip(0, 100) / 100

# %%
# SMILES正規化と不正データ除去
for col in ["REAGENT", "REACTANT", "PRODUCT"]:
    df[col] = df[col].apply(space_clean)
    df[col] = df[col].apply(lambda x: canonicalize(x) if x != " " else " ")
    df = df[~df[col].isna()].reset_index(drop=True)
    df[col] = df[col].apply(lambda x: ".".join(sorted(x.split("."))))

# %%
# CATALYST、REAGENT、SOLVENTを統合
df["REAGENT"] = df["CATALYST"].fillna(" ") + "." + df["REAGENT"].fillna(" ") + "." + df["SOLVENT"].fillna(" ")
print(f"前処理後のデータ数: {len(df)}")
# Out:
# 前処理後のデータ数: 1518

# %% [markdown]
# ## Morgan Fingerprintの計算

# %%
def smiles_to_morgan_fingerprint(smiles, radius=2, n_bits=2048):
    """
    SMILESからMorgan Fingerprintを計算
    
    Args:
        smiles: SMILES文字列
        radius: Morgan Fingerprintの半径（デフォルト: 2）
        n_bits: ビット数（デフォルト: 2048）
    
    Returns:
        numpy array: フィンガープリントのビットベクトル
    """
    try:
        mol = Chem.MolFromSmiles(smiles)
        if mol is None:
            return np.zeros(n_bits)
        fp = rdFingerprintGenerator.GetMorganGenerator(mol, radius, n_bits)
        return np.array(fp)
    except:
        return np.zeros(n_bits)

def reaction_to_fingerprint(reactant, reagent, product, radius=2, n_bits=2048):
    """
    反応物、試薬、生成物からMorgan Fingerprintを結合
    
    Args:
        reactant: 反応物のSMILES
        reagent: 試薬のSMILES
        product: 生成物のSMILES
        radius: Morgan Fingerprintの半径
        n_bits: 各分子のフィンガープリントのビット数
    
    Returns:
        numpy array: 結合されたフィンガープリント
    """
    fp_reactant = smiles_to_morgan_fingerprint(reactant, radius, n_bits)
    fp_reagent = smiles_to_morgan_fingerprint(reagent, radius, n_bits)
    fp_product = smiles_to_morgan_fingerprint(product, radius, n_bits)
    
    # 3つのフィンガープリントを結合
    return np.concatenate([fp_reactant, fp_reagent, fp_product])

# %%
# 全データのフィンガープリントを計算
print("Morgan Fingerprintを計算中...")
fingerprints = []
for idx, row in df.iterrows():
    fp = reaction_to_fingerprint(row["REACTANT"], row["REAGENT"], row["PRODUCT"])
    fingerprints.append(fp)
    if (idx + 1) % 100 == 0:
        print(f"  {idx + 1}/{len(df)} 完了")

X = np.array(fingerprints)
y = df["YIELD"].values * 100  # パーセント表記に戻す

print(f"\nフィンガープリントの形状: {X.shape}")
print(f"収率の範囲: {y.min():.2f}% - {y.max():.2f}%")
# Out:
# Morgan Fingerprintを計算中...
#   100/1518 完了
#   200/1518 完了
#   300/1518 完了
#   400/1518 完了
#   500/1518 完了
#   600/1518 完了
#   700/1518 完了
#   800/1518 完了
#   900/1518 完了
#   1000/1518 完了
#   1100/1518 完了
#   1200/1518 完了
#   1300/1518 完了
#   1400/1518 完了
#   1500/1518 完了
#
# フィンガープリントの形状: (1518, 6144)
# 収率の範囲: 0.00% - 100.00%

# %% [markdown]
# ## ガウス過程回帰モデルの構築

# %%
from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.gaussian_process.kernels import RBF, ConstantKernel as C, WhiteKernel
from scipy.stats import norm
import matplotlib.pyplot as plt
import os
import csv

# %%
def create_reaction_dictionaries(df):
    """
    データセットから反応辞書を作成
    
    Returns:
        tuple: (reactant_list, reagent_list, product_list, product_dict, true_yield_dict, fingerprint_dict)
    """
    reactant_list = sorted(df["REACTANT"].unique())
    reagent_list = sorted(df["REAGENT"].unique())
    product_list = sorted(df["PRODUCT"].unique())
    
    # (reactant, reagent) -> product のマッピング
    product_dict = {
        (row["REACTANT"], row["REAGENT"]): row["PRODUCT"]
        for _, row in df.iterrows()
    }
    
    # (reactant, reagent, product) -> yield のマッピング
    true_yield_dict = {
        (row["REACTANT"], row["REAGENT"], row["PRODUCT"]): row["YIELD"] * 100
        for _, row in df.iterrows()
    }
    
    # (reactant, reagent, product) -> fingerprint のマッピング
    fingerprint_dict = {}
    for idx, row in df.iterrows():
        key = (row["REACTANT"], row["REAGENT"], row["PRODUCT"])
        fingerprint_dict[key] = X[idx]
    
    print(f"Reactant候補数: {len(reactant_list)}")
    print(f"Reagent候補数: {len(reagent_list)}")
    print(f"Product候補数: {len(product_list)}")
    print(f"既知の組み合わせ数: {len(product_dict)}")
    
    return reactant_list, reagent_list, product_list, product_dict, true_yield_dict, fingerprint_dict

# %%
# 辞書の作成
reactant_list, reagent_list, product_list, product_dict, true_yield_dict, fingerprint_dict = create_reaction_dictionaries(df)
# Out:
# Reactant候補数: 33
# Reagent候補数: 46
# Product候補数: 24
# 既知の組み合わせ数: 1518

# %% [markdown]
# ## ベイズ最適化の実装

# %%
class GaussianProcessBayesianOptimization:
    """
    ガウス過程回帰を使用したベイズ最適化
    Morgan Fingerprintを特徴量として使用
    """
    
    def __init__(self, reactant_list, reagent_list, product_dict, true_yield_dict, fingerprint_dict, output_dir="../runs/gpr_yield_NiB"):
        """
        Args:
            reactant_list: reactantの候補リスト
            reagent_list: reagentの候補リスト
            product_dict: (reactant, reagent) -> product のマッピング辞書
            true_yield_dict: (reactant, reagent, product) -> yield のマッピング辞書
            fingerprint_dict: (reactant, reagent, product) -> fingerprint のマッピング辞書
            output_dir: 出力ディレクトリ
        """
        self.reactant_list = reactant_list
        self.reagent_list = reagent_list
        self.product_dict = product_dict
        self.true_yield_dict = true_yield_dict
        self.fingerprint_dict = fingerprint_dict
        self.output_dir = output_dir
        
        # 全ての有効な組み合わせを事前計算
        self.valid_combinations = []
        for reactant in reactant_list:
            for reagent in reagent_list:
                if (reactant, reagent) in product_dict:
                    self.valid_combinations.append((reactant, reagent))
        
        print(f"有効な組み合わせ数: {len(self.valid_combinations)}")
        
        # ガウス過程回帰モデルの初期化
        kernel = C(1.0, (1e-3, 1e3)) * RBF(1.0, (1e-2, 1e2)) + WhiteKernel(noise_level=1.0)
        self.gp_model = GaussianProcessRegressor(
            kernel=kernel,
            n_restarts_optimizer=10,
            normalize_y=True,
            alpha=1e-6
        )
        
        # 実験結果の記録
        self.experiment_history = []
        self.tried_combinations = set()
        self.X_train = []  # 学習用フィンガープリント
        self.y_train = []  # 学習用収率
        
        # 出力ディレクトリの作成
        os.makedirs(output_dir, exist_ok=True)
        self.log_csv_path = os.path.join(output_dir, "optimization_log.csv")
        self._init_csv_log()
    
    def _init_csv_log(self):
        """CSVログファイルの初期化"""
        if not os.path.exists(self.log_csv_path):
            with open(self.log_csv_path, "w", newline="", encoding="utf-8") as f:
                writer = csv.writer(f)
                writer.writerow([
                    "trial", "reactant", "reagent", "product",
                    "predicted_mean", "predicted_std", "actual_yield",
                    "error_pct", "acquisition_value"
                ])
    
    def _log_experiment_to_csv(self, experiment_result):
        """実験結果をCSVに記録"""
        with open(self.log_csv_path, "a", newline="", encoding="utf-8") as f:
            writer = csv.writer(f)
            writer.writerow([
                experiment_result['trial'],
                experiment_result['reactant'],
                experiment_result['reagent'],
                experiment_result['product'],
                f"{experiment_result['predicted_mean']:.6f}",
                f"{experiment_result['predicted_std']:.6f}",
                f"{experiment_result['actual_yield']:.6f}",
                f"{experiment_result['error_pct']:+.6f}",
                f"{experiment_result['acquisition_value']:.6f}"
            ])
    
    def _predict_yield_with_uncertainty(self, fingerprints):
        """
        ガウス過程回帰による予測と不確実性の推定
        
        Args:
            fingerprints: フィンガープリントの配列 (n_samples, n_features)
        
        Returns:
            tuple: (予測平均, 予測標準偏差)
        """
        if len(self.X_train) == 0:
            # 初期状態ではランダムな予測
            n_samples = fingerprints.shape[0] if len(fingerprints.shape) > 1 else 1
            return np.ones(n_samples) * 50.0, np.ones(n_samples) * 30.0
        
        mean, std = self.gp_model.predict(fingerprints, return_std=True)
        return mean, std
    
    def _acquisition_function(self, mean, std, best_observed_yield, xi=0.01):
        """
        期待改善量（Expected Improvement）による獲得関数
        
        Args:
            mean: 予測平均
            std: 予測標準偏差
            best_observed_yield: これまでの最良収率
            xi: 探索と活用のトレードオフパラメータ
        
        Returns:
            期待改善量
        """
        if isinstance(std, np.ndarray):
            std = np.maximum(std, 1e-9)  # 数値安定性のため
        else:
            std = max(std, 1e-9)
        
        z = (mean - best_observed_yield - xi) / std
        ei = (mean - best_observed_yield - xi) * norm.cdf(z) + std * norm.pdf(z)
        return ei
    
    def _get_best_observed_yield(self):
        """これまでの最良収率を取得"""
        if len(self.experiment_history) > 0:
            return max([exp['actual_yield'] for exp in self.experiment_history])
        else:
            return 0.0
    
    def _select_next_candidate(self):
        """
        獲得関数に基づいて次の候補を選択
        """
        # 未試行の組み合わせを取得
        untried_combinations = [
            combo for combo in self.valid_combinations 
            if combo not in self.tried_combinations
        ]
        
        if not untried_combinations:
            print("全ての組み合わせを試行済みです。")
            return None
        
        # 獲得関数を計算
        best_yield = self._get_best_observed_yield()
        
        # フィンガープリントのリストを作成
        fingerprints = []
        for reactant, reagent in untried_combinations:
            product = self.product_dict[(reactant, reagent)]
            fp = self.fingerprint_dict[(reactant, reagent, product)]
            fingerprints.append(fp)
        
        fingerprints = np.array(fingerprints)
        
        print(f"獲得関数値を計算中... ({len(untried_combinations)}個の候補)")
        
        try:
            # バッチで予測実行
            pred_means, pred_stds = self._predict_yield_with_uncertainty(fingerprints)
            
            # 獲得関数値を計算
            acq_values = self._acquisition_function(pred_means, pred_stds, best_yield)
            
            # 最大獲得関数値のインデックス
            best_idx = np.argmax(acq_values)
            selected_combo = untried_combinations[best_idx]
            
            print(f"🎯 選択: {selected_combo} (EI: {acq_values[best_idx]:.4f})")
            
            return selected_combo
            
        except Exception as e:
            print(f"❌ エラー: {e}")
            # エラー時はランダム選択
            import random
            return random.choice(untried_combinations)
    
    def _evaluate_candidate(self, reactant, reagent, trial_num):
        """候補を評価（実験を実行）"""
        product = self.product_dict[(reactant, reagent)]
        fp = self.fingerprint_dict[(reactant, reagent, product)]
        
        # ガウス過程回帰による予測
        try:
            pred_mean, pred_std = self._predict_yield_with_uncertainty(fp.reshape(1, -1))
            pred_mean = float(pred_mean[0])
            pred_std = float(pred_std[0])
        except Exception as e:
            print(f"❌ 予測エラー: {e}")
            return None
        
        # 実際の収率を取得
        key = (reactant, reagent, product)
        actual_yield = self.true_yield_dict.get(key)
        
        if actual_yield is None:
            print(f"❗ 真値なし: {reactant} + {reagent} → {product}")
            actual_yield = 0.0
        
        # 獲得関数の計算
        best_yield = self._get_best_observed_yield()
        acquisition_value = float(self._acquisition_function(pred_mean, pred_std, best_yield))
        
        # 誤差の計算
        error_pct = pred_mean - actual_yield
        
        # 実験結果を記録
        experiment_result = {
            'trial': trial_num,
            'reactant': reactant,
            'reagent': reagent,
            'product': product,
            'predicted_mean': pred_mean,
            'predicted_std': pred_std,
            'actual_yield': actual_yield,
            'error_pct': error_pct,
            'acquisition_value': acquisition_value
        }
        
        # 出力
        print(f"🔎 Trial {trial_num}: {reactant} + {reagent} → {product}")
        print(f"   📈 予測: {pred_mean:.2f}% ± {pred_std:.2f}%")
        print(f"   🧪 真値: {actual_yield:.2f}%")
        print(f"   ❗ 誤差: {error_pct:+.2f}%")
        print(f"   🎯 獲得関数: {acquisition_value:.4f}")
        
        return experiment_result
    
    def _update_model(self, fingerprint, yield_value):
        """新しいデータでモデルを更新"""
        self.X_train.append(fingerprint)
        self.y_train.append(yield_value)
        
        # ガウス過程モデルを再学習
        X_train_array = np.array(self.X_train)
        y_train_array = np.array(self.y_train)
        
        print(f"   🔄 モデル更新中... (学習データ数: {len(self.X_train)})")
        self.gp_model.fit(X_train_array, y_train_array)
    
    def optimize(self, n_trials=50):
        """ベイズ最適化の実行"""
        print(f"ガウス過程ベイズ最適化を開始 ({n_trials}試行)")
        print("="*60)
        
        for trial in range(1, n_trials + 1):
            # 次の候補を選択
            candidate = self._select_next_candidate()
            if candidate is None:
                print("全ての組み合わせを試行完了。")
                break
            
            reactant, reagent = candidate
            product = self.product_dict[(reactant, reagent)]
            
            # 候補を評価
            result = self._evaluate_candidate(reactant, reagent, trial)
            if result is None:
                continue
            
            # 結果を記録
            self.experiment_history.append(result)
            self.tried_combinations.add((reactant, reagent))
            
            # CSVに記録
            self._log_experiment_to_csv(result)
            
            # モデルを更新
            fp = self.fingerprint_dict[(reactant, reagent, product)]
            self._update_model(fp, result['actual_yield'])
            
            # 進捗表示
            current_best = max([exp['actual_yield'] for exp in self.experiment_history])
            print(f"   💡 現在の最高収率: {current_best:.2f}%")
            print("-" * 60)
        
        print(f"\n最適化完了! 総試行数: {len(self.experiment_history)}")
        
        # 最終結果
        if self.experiment_history:
            best_exp = max(self.experiment_history, key=lambda x: x['actual_yield'])
            print(f"🏆 最高収率: {best_exp['actual_yield']:.2f}%")
            print(f"🏆 最適組み合わせ: {best_exp['reactant']} + {best_exp['reagent']} → {best_exp['product']}")
            return best_exp
        else:
            return None
    
    def get_optimization_summary(self):
        """最適化の概要統計を取得"""
        if not self.experiment_history:
            return {}
        
        actual_yields = [exp['actual_yield'] for exp in self.experiment_history]
        predicted_means = [exp['predicted_mean'] for exp in self.experiment_history]
        errors = [exp['error_pct'] for exp in self.experiment_history]
        
        return {
            'total_trials': len(self.experiment_history),
            'max_yield': max(actual_yields),
            'mean_yield': np.mean(actual_yields),
            'std_yield': np.std(actual_yields),
            'mae_error': np.mean(np.abs(errors)),
            'rmse_error': np.sqrt(np.mean(np.array(errors)**2)),
            'coverage': len(self.tried_combinations) / len(self.valid_combinations) * 100,
            'log_path': self.log_csv_path
        }
    
    def save_visualization(self):
        """最適化結果を可視化して保存"""
        if not self.experiment_history:
            print("実験履歴がありません。")
            return
        
        save_dir = os.path.join(self.output_dir, "visualization")
        os.makedirs(save_dir, exist_ok=True)
        
        trials = [exp['trial'] for exp in self.experiment_history]
        actual_yields = [exp['actual_yield'] for exp in self.experiment_history]
        predicted_means = [exp['predicted_mean'] for exp in self.experiment_history]
        predicted_stds = [exp['predicted_std'] for exp in self.experiment_history]
        errors = [exp['error_pct'] for exp in self.experiment_history]
        
        # 累積最大値
        cumulative_max = np.maximum.accumulate(actual_yields)
        
        # 1. Optimization Progress
        fig = plt.figure(figsize=(8, 5))
        plt.plot(trials, actual_yields, 'o-', alpha=0.6, label='Actual Yield', markersize=6)
        plt.plot(trials, cumulative_max, 'r-', linewidth=3, label='Best So Far')
        plt.xlabel('Trial')
        plt.ylabel('Yield [%]')
        plt.title('Optimization Progress')
        plt.legend()
        plt.grid(True, alpha=0.3)
        plt.tight_layout()
        plt.savefig(os.path.join(save_dir, 'optimization_progress.png'), dpi=180, bbox_inches='tight')
        plt.close(fig)
        
        # 2. Parity Plot
        fig = plt.figure(figsize=(6, 6))
        plt.scatter(actual_yields, predicted_means, s=50, alpha=0.6)
        lims = [0, 100]
        plt.plot(lims, lims, 'r--', label='Perfect Prediction')
        plt.xlim(lims)
        plt.ylim(lims)
        plt.xlabel('Actual Yield [%]')
        plt.ylabel('Predicted Yield [%]')
        plt.title('Parity Plot')
        plt.legend()
        plt.grid(True, alpha=0.3)
        plt.tight_layout()
        plt.savefig(os.path.join(save_dir, 'parity.png'), dpi=180, bbox_inches='tight')
        plt.close(fig)
        
        # 3. Prediction Uncertainty
        fig = plt.figure(figsize=(8, 5))
        plt.errorbar(trials, predicted_means, yerr=predicted_stds,
                    fmt='o', alpha=0.6, capsize=5, label='Prediction ± Uncertainty')
        plt.plot(trials, actual_yields, 'ro', alpha=0.6, label='Actual Yield')
        plt.xlabel('Trial')
        plt.ylabel('Yield [%]')
        plt.title('Prediction Uncertainty')
        plt.legend()
        plt.grid(True, alpha=0.3)
        plt.tight_layout()
        plt.savefig(os.path.join(save_dir, 'uncertainty.png'), dpi=180, bbox_inches='tight')
        plt.close(fig)
        
        # 4. Error Trend
        fig = plt.figure(figsize=(8, 5))
        plt.plot(trials, errors, 'o-', alpha=0.6)
        plt.axhline(0, color='r', linestyle='--', label='Perfect Prediction')
        plt.xlabel('Trial')
        plt.ylabel('Prediction Error [%]')
        plt.title('Prediction Error Trend')
        plt.legend()
        plt.grid(True, alpha=0.3)
        plt.tight_layout()
        plt.savefig(os.path.join(save_dir, 'error_trend.png'), dpi=180, bbox_inches='tight')
        plt.close(fig)
        
        # 5. Error Histogram
        fig = plt.figure(figsize=(7, 5))
        plt.hist(errors, bins=30, alpha=0.7, edgecolor='black')
        plt.axvline(0, color='r', linestyle='--', label='Perfect Prediction')
        plt.xlabel('Prediction Error [%]')
        plt.ylabel('Count')
        plt.title('Error Distribution')
        plt.legend()
        plt.grid(True, alpha=0.3)
        plt.tight_layout()
        plt.savefig(os.path.join(save_dir, 'error_hist.png'), dpi=180, bbox_inches='tight')
        plt.close(fig)
        
        # 6. Uncertainty vs Actual Yield
        fig = plt.figure(figsize=(7, 5))
        plt.scatter(predicted_stds, actual_yields, alpha=0.6)
        plt.xlabel('Prediction Uncertainty (Std)')
        plt.ylabel('Actual Yield [%]')
        plt.title('Uncertainty vs Actual Yield')
        plt.grid(True, alpha=0.3)
        plt.tight_layout()
        plt.savefig(os.path.join(save_dir, 'uncertainty_vs_yield.png'), dpi=180, bbox_inches='tight')
        plt.close(fig)
        
        print(f"可視化完了! 保存先: {save_dir}")

# %% [markdown]
# ## ベイズ最適化の実行

# %%
# ベイズ最適化器を初期化
gp_optimizer = GaussianProcessBayesianOptimization(
    reactant_list=reactant_list,
    reagent_list=reagent_list,
    product_dict=product_dict,
    true_yield_dict=true_yield_dict,
    fingerprint_dict=fingerprint_dict,
    output_dir="../runs/gpr_100trials_NiB"
)
# Out:
# 有効な組み合わせ数: 1518

# %%
# ベイズ最適化の実行
best_result = gp_optimizer.optimize(n_trials=100)

# 最適化の概要統計を表示
summary = gp_optimizer.get_optimization_summary()
print(f"\n=== 最適化概要 ===")
print(f"総試行数: {summary.get('total_trials', 0)}")
print(f"最高収率: {summary.get('max_yield', 0):.2f}%")
print(f"平均収率: {summary.get('mean_yield', 0):.2f}%")
print(f"収率標準偏差: {summary.get('std_yield', 0):.2f}%")
print(f"予測誤差 (MAE): {summary.get('mae_error', 0):.2f}%")
print(f"予測誤差 (RMSE): {summary.get('rmse_error', 0):.2f}%")
print(f"探索範囲: {summary.get('coverage', 0):.1f}%")
print(f"ログファイル: {summary.get('log_path', 'N/A')}")

# 可視化を保存
gp_optimizer.save_visualization()
# Out:
# ガウス過程ベイズ最適化を開始 (100試行)
# ============================================================
# 獲得関数値を計算中... (1518個の候補)
# 🎯 選択: ('Brc1ccc(-c2ccccc2)cc1', 'C1CCC([PH+](C2CCCCC2)C2CCCCC2)CC1.F[B-](F)(F)F.OB(O)B(O)O.CCO') (EI: 50.5853)
# 🔎 Trial 1: Brc1ccc(-c2ccccc2)cc1 + C1CCC([PH+](C2CCCCC2)C2CCCCC2)CC1.F[B-](F)(F)F.OB(O)B(O)O.CCO → OB(O)c1ccc(-c2ccccc2)cc1
#    📈 予測: 50.00% ± 30.00%
#    🧪 真値: 53.22%
#    ❗ 誤差: -3.22%
#    🎯 獲得関数: 50.5853
#    🔄 モデル更新中... (学習データ数: 1)
#    💡 現在の最高収率: 53.22%
# ------------------------------------------------------------
# 獲得関数値を計算中... (1517個の候補)
# 🎯 選択: ('Brc1ccc(-c2ccccc2)cc1', 'C1CCC([PH+](C2CCCCC2)C2CCCCC2)CC1.F[B-](F)(F)F.OB(O)B(O)O.CO') (EI: 0.0000)
# 🔎 Trial 2: Brc1ccc(-c2ccccc2)cc1 + C1CCC([PH+](C2CCCCC2)C2CCCCC2)CC1.F[B-](F)(F)F.OB(O)B(O)O.CO → OB(O)c1ccc(-c2ccccc2)cc1
#    📈 予測: 53.22% ± 0.00%
#    🧪 真値: 56.59%
#    ❗ 誤差: -3.37%
#    🎯 獲得関数: 0.0000
#    🔄 モデル更新中... (学習データ数: 2)
#    💡 現在の最高収率: 56.59%
# ------------------------------------------------------------
# 獲得関数値を計算中... (1516個の候補)
# 🎯 選択: ('Brc1ccc(-c2ccccc2)cc1', 'CC(=C(c1ccccc1)c1ccccc1)P(C1CCCCC1)C1CCCCC1.OB(O)B(O)O.CCO') (EI: 0.1392)
# 🔎 Trial 3: Brc1ccc(-c2ccccc2)cc1 + CC(=C(c1ccccc1)c1ccccc1)P(C1CCCCC1)C1CCCCC1.OB(O)B(O)O.CCO → OB(O)c1ccc(-c2ccccc2)cc1
#    📈 予測: 54.90% ± 1.69%
#    🧪 真値: 44.09%
#    ❗ 誤差: +10.82%
#    🎯 獲得関数: 0.1392
#    🔄 モデル更新中... (学習データ数: 3)
#    💡 現在の最高収率: 56.59%
# ------------------------------------------------------------
# 獲得関数値を計算中... (1515個の候補)
# 🎯 選択: ('Brc1ccc(-c2ccccc2)cc1', 'CC(=C(c1ccccc1)c1ccccc1)P(C1CCCCC1)C1CCCCC1.OB(O)B(O)O.CO') (EI: 0.4382)
# 🔎 Trial 4: Brc1ccc(-c2ccccc2)cc1 + CC(=C(c1ccccc1)c1ccccc1)P(C1CCCCC1)C1CCCCC1.OB(O)B(O)O.CO → OB(O)c1ccc(-c2ccccc2)cc1
#    📈 予測: 51.30% ± 5.29%
#    🧪 真値: 41.50%
#    ❗ 誤差: +9.80%
#    🎯 獲得関数: 0.4382
#    🔄 モデル更新中... (学習データ数: 4)
#    💡 現在の最高収率: 56.59%
# ------------------------------------------------------------
# 獲得関数値を計算中... (1514個の候補)
# 🎯 選択: ('Brc1ccc(-c2ccccc2)cc1', 'CC(C)(C)P(c1ccccc1)C(C)(C)C.OB(O)B(O)O.CCO') (EI: 0.3218)
# 🔎 Trial 5: Brc1ccc(-c2ccccc2)cc1 + CC(C)(C)P(c1ccccc1)C(C)(C)C.OB(O)B(O)O.CCO → OB(O)c1ccc(-c2ccccc2)cc1
#    📈 予測: 48.85% ± 6.24%
#    🧪 真値: 30.03%
#    ❗ 誤差: +18.82%
#    🎯 獲得関数: 0.3218
#    🔄 モデル更新中... (学習データ数: 5)
#    💡 現在の最高収率: 56.59%
# ------------------------------------------------------------
# 獲得関数値を計算中... (1513個の候補)
# 🎯 選択: ('Brc1ccc(-c2ccccc2)cc1', 'CC(C)(C)P(c1ccccc1)C(C)(C)C.OB(O)B(O)O.CO') (EI: 0.4972)
# 🔎 Trial 6: Brc1ccc(-c2ccccc2)cc1 + CC(C)(C)P(c1ccccc1)C(C)(C)C.OB(O)B(O)O.CO → OB(O)c1ccc(-c2ccccc2)cc1
#    📈 予測: 45.09% ± 9.38%
#    🧪 真値: 39.66%
#    ❗ 誤差: +5.43%
#    🎯 獲得関数: 0.4972
#    🔄 モデル更新中... (学習データ数: 6)
#    💡 現在の最高収率: 56.59%
# ------------------------------------------------------------
# 獲得関数値を計算中... (1512個の候補)
# 🎯 選択: ('Brc1ccc(-c2ccccc2)cc1', 'CC(C)c1cc(C(C)C)c(-c2ccccc2P(c2ccccc2)c2ccccc2)c(C(C)C)c1.OB(O)B(O)O.CCO') (EI: 0.3146)
# 🔎 Trial 7: Brc1ccc(-c2ccccc2)cc1 + CC(C)c1cc(C(C)C)c(-c2ccccc2P(c2ccccc2)c2ccccc2)c(C(C)C)c1.OB(O)B(O)O.CCO → OB(O)c1ccc(-c2ccccc2)cc1
#    📈 予測: 44.18% ± 8.80%
#    🧪 真値: 81.68%
#    ❗ 誤差: -37.50%
#    🎯 獲得関数: 0.3146
#    🔄 モデル更新中... (学習データ数: 7)
#    💡 現在の最高収率: 81.68%
# ------------------------------------------------------------
# 獲得関数値を計算中... (1511個の候補)
# 🎯 選択: ('Brc1ccc(-c2ccccc2)cc1', 'CC(C)c1cc(C(C)C)c(-c2ccccc2P(c2ccccc2)c2ccccc2)c(C(C)C)c1.OB(O)B(O)O.CO') (EI: 0.1056)
# 🔎 Trial 8: Brc1ccc(-c2ccccc2)cc1 + CC(C)c1cc(C(C)C)c(-c2ccccc2P(c2ccccc2)c2ccccc2)c(C(C)C)c1.OB(O)B(O)O.CO → OB(O)c1ccc(-c2ccccc2)cc1
#    📈 予測: 49.54% ± 15.46%
#    🧪 真値: 63.23%
#    ❗ 誤差: -13.69%
#    🎯 獲得関数: 0.1056
#    🔄 モデル更新中... (学習データ数: 8)
#    💡 現在の最高収率: 81.68%
# ------------------------------------------------------------
# 獲得関数値を計算中... (1510個の候補)
# 🎯 選択: ('Brc1ccc(-c2ccccc2)cc1', 'CCCCC1([PH+](C2CCCCC2)C2CCCCC2)c2ccccc2-c2ccccc21.F[B-](F)(F)F.OB(O)B(O)O.CCO') (EI: 0.1256)
# 🔎 Trial 9: Brc1ccc(-c2ccccc2)cc1 + CCCCC1([PH+](C2CCCCC2)C2CCCCC2)c2ccccc2-c2ccccc21.F[B-](F)(F)F.OB(O)B(O)O.CCO → OB(O)c1ccc(-c2ccccc2)cc1
#    📈 予測: 51.25% ± 15.15%
#    🧪 真値: 69.31%
#    ❗ 誤差: -18.06%
#    🎯 獲得関数: 0.1256
#    🔄 モデル更新中... (学習データ数: 9)
#    💡 現在の最高収率: 81.68%
# ------------------------------------------------------------
# 獲得関数値を計算中... (1509個の候補)
# 🎯 選択: ('Brc1ccc(-c2ccccc2)cc1', 'CCCCC1([PH+](C2CCCCC2)C2CCCCC2)c2ccccc2-c2ccccc21.F[B-](F)(F)F.OB(O)B(O)O.CO') (EI: 0.1935)
# 🔎 Trial 10: Brc1ccc(-c2ccccc2)cc1 + CCCCC1([PH+](C2CCCCC2)C2CCCCC2)c2ccccc2-c2ccccc21.F[B-](F)(F)F.OB(O)B(O)O.CO → OB(O)c1ccc(-c2ccccc2)cc1
#    📈 予測: 53.26% ± 15.37%
#    🧪 真値: 51.67%
#    ❗ 誤差: +1.58%
#    🎯 獲得関数: 0.1935
#    🔄 モデル更新中... (学習データ数: 10)
#    💡 現在の最高収率: 81.68%
# ------------------------------------------------------------
# 獲得関数値を計算中... (1508個の候補)
# 🎯 選択: ('Brc1ccc(-c2ccccc2)cc1', 'CN(C)c1ccc(P(c2ccccc2)c2ccccc2)cc1.OB(O)B(O)O.CCO') (EI: 0.1380)
# 🔎 Trial 11: Brc1ccc(-c2ccccc2)cc1 + CN(C)c1ccc(P(c2ccccc2)c2ccccc2)cc1.OB(O)B(O)O.CCO → OB(O)c1ccc(-c2ccccc2)cc1
#    📈 予測: 53.10% ± 14.59%
#    🧪 真値: 95.88%
#    ❗ 誤差: -42.78%
#    🎯 獲得関数: 0.1380
#    🔄 モデル更新中... (学習データ数: 11)
#    💡 現在の最高収率: 95.88%
# ------------------------------------------------------------
# 獲得関数値を計算中... (1507個の候補)
# 🎯 選択: ('Brc1ccc(-c2ccccc2)cc1', 'CN(C)c1ccc(P(c2ccccc2)c2ccccc2)cc1.OB(O)B(O)O.CO') (EI: 0.1222)
# 🔎 Trial 12: Brc1ccc(-c2ccccc2)cc1 + CN(C)c1ccc(P(c2ccccc2)c2ccccc2)cc1.OB(O)B(O)O.CO → OB(O)c1ccc(-c2ccccc2)cc1
#    📈 予測: 56.99% ± 18.58%
#    🧪 真値: 79.59%
#    ❗ 誤差: -22.61%
#    🎯 獲得関数: 0.1222
#    🔄 モデル更新中... (学習データ数: 12)
#    💡 現在の最高収率: 95.88%
# ------------------------------------------------------------
# 獲得関数値を計算中... (1506個の候補)
# 🎯 選択: ('Brc1ccc(-c2ccccc2)cc1', 'CN(C)c1ccccc1-c1ccccc1P(c1ccccc1)c1ccccc1.OB(O)B(O)O.CCO') (EI: 0.1765)
# 🔎 Trial 13: Brc1ccc(-c2ccccc2)cc1 + CN(C)c1ccccc1-c1ccccc1P(c1ccccc1)c1ccccc1.OB(O)B(O)O.CCO → OB(O)c1ccc(-c2ccccc2)cc1
#    📈 予測: 58.87% ± 18.85%
#    🧪 真値: 88.26%
#    ❗ 誤差: -29.39%
#    🎯 獲得関数: 0.1765
#    🔄 モデル更新中... (学習データ数: 13)
#    💡 現在の最高収率: 95.88%
# ------------------------------------------------------------
# 獲得関数値を計算中... (1505個の候補)
# 🎯 選択: ('Brc1ccc(-c2ccccc2)cc1', 'CN(C)c1ccccc1-c1ccccc1P(c1ccccc1)c1ccccc1.OB(O)B(O)O.CO') (EI: 0.3108)
# 🔎 Trial 14: Brc1ccc(-c2ccccc2)cc1 + CN(C)c1ccccc1-c1ccccc1P(c1ccccc1)c1ccccc1.OB(O)B(O)O.CO → OB(O)c1ccc(-c2ccccc2)cc1
#    📈 予測: 61.13% ± 19.74%
#    🧪 真値: 88.17%
#    ❗ 誤差: -27.03%
#    🎯 獲得関数: 0.3108
#    🔄 モデル更新中... (学習データ数: 14)
#    💡 現在の最高収率: 95.88%
# ------------------------------------------------------------
# 獲得関数値を計算中... (1504個の候補)
# 🎯 選択: ('Brc1ccc(-c2ccccc2)cc1', 'COc1cc(C(C)(C)C)cc(C(C)(C)C)c1-c1ccccc1P(C1CCCCC1)C1CCCCC1.OB(O)B(O)O.CCO') (EI: 0.4486)
# 🔎 Trial 15: Brc1ccc(-c2ccccc2)cc1 + COc1cc(C(C)(C)C)cc(C(C)(C)C)c1-c1ccccc1P(C1CCCCC1)C1CCCCC1.OB(O)B(O)O.CCO → OB(O)c1ccc(-c2ccccc2)cc1
#    📈 予測: 63.06% ± 20.26%
#    🧪 真値: 68.17%
#    ❗ 誤差: -5.11%
#    🎯 獲得関数: 0.4486
#    🔄 モデル更新中... (学習データ数: 15)
#    💡 現在の最高収率: 95.88%
# ------------------------------------------------------------
# 獲得関数値を計算中... (1503個の候補)
# 🎯 選択: ('Brc1ccc(-c2ccccc2)cc1', 'COc1cc(C(C)(C)C)cc(C(C)(C)C)c1-c1ccccc1P(C1CCCCC1)C1CCCCC1.OB(O)B(O)O.CO') (EI: 0.3986)
# 🔎 Trial 16: Brc1ccc(-c2ccccc2)cc1 + COc1cc(C(C)(C)C)cc(C(C)(C)C)c1-c1ccccc1P(C1CCCCC1)C1CCCCC1.OB(O)B(O)O.CO → OB(O)c1ccc(-c2ccccc2)cc1
#    📈 予測: 63.40% ± 19.61%
#    🧪 真値: 46.77%
#    ❗ 誤差: +16.63%
#    🎯 獲得関数: 0.3986
#    🔄 モデル更新中... (学習データ数: 16)
#    💡 現在の最高収率: 95.88%
# ------------------------------------------------------------
# 獲得関数値を計算中... (1502個の候補)
# 🎯 選択: ('Brc1ccc(-c2ccccc2)cc1', 'COc1ccc(P(c2ccc(OC)cc2)c2ccc(OC)cc2)cc1.OB(O)B(O)O.CCO') (EI: 0.3323)
# 🔎 Trial 17: Brc1ccc(-c2ccccc2)cc1 + COc1ccc(P(c2ccc(OC)cc2)c2ccc(OC)cc2)cc1.OB(O)B(O)O.CCO → OB(O)c1ccc(-c2ccccc2)cc1
#    📈 予測: 62.36% ± 19.41%
#    🧪 真値: 96.12%
#    ❗ 誤差: -33.76%
#    🎯 獲得関数: 0.3323
#    🔄 モデル更新中... (学習データ数: 17)
#    💡 現在の最高収率: 96.12%
# ------------------------------------------------------------
# 獲得関数値を計算中... (1501個の候補)
# 🎯 選択: ('Brc1ccc(-c2ccccc2)cc1', 'COc1ccc(P(c2ccc(OC)cc2)c2ccc(OC)cc2)cc1.OB(O)B(O)O.CO') (EI: 0.5281)
# 🔎 Trial 18: Brc1ccc(-c2ccccc2)cc1 + COc1ccc(P(c2ccc(OC)cc2)c2ccc(OC)cc2)cc1.OB(O)B(O)O.CO → OB(O)c1ccc(-c2ccccc2)cc1
#    📈 予測: 64.35% ± 20.44%
#    🧪 真値: 81.42%
#    ❗ 誤差: -17.08%
#    🎯 獲得関数: 0.5281
#    🔄 モデル更新中... (学習データ数: 18)
#    💡 現在の最高収率: 96.12%
# ------------------------------------------------------------
# 獲得関数値を計算中... (1500個の候補)
# 🎯 選択: ('Brc1ccc(-c2ccccc2)cc1', 'COc1cccc(OC)c1-c1ccccc1P(c1ccccc1)c1ccccc1.OB(O)B(O)O.CCO') (EI: 0.5632)
# 🔎 Trial 19: Brc1ccc(-c2ccccc2)cc1 + COc1cccc(OC)c1-c1ccccc1P(c1ccccc1)c1ccccc1.OB(O)B(O)O.CCO → OB(O)c1ccc(-c2ccccc2)cc1
#    📈 予測: 65.30% ± 20.25%
#    🧪 真値: 87.63%
#    ❗ 誤差: -22.33%
#    🎯 獲得関数: 0.5632
#    🔄 モデル更新中... (学習データ数: 19)
#    💡 現在の最高収率: 96.12%
# ------------------------------------------------------------
# 獲得関数値を計算中... (1499個の候補)
# 🎯 選択: ('Brc1ccc(-c2ccccc2)cc1', 'COc1cccc(OC)c1-c1ccccc1P(c1ccccc1)c1ccccc1.OB(O)B(O)O.CO') (EI: 0.6539)
# 🔎 Trial 20: Brc1ccc(-c2ccccc2)cc1 + COc1cccc(OC)c1-c1ccccc1P(c1ccccc1)c1ccccc1.OB(O)B(O)O.CO → OB(O)c1ccc(-c2ccccc2)cc1
#    📈 予測: 66.47% ± 20.33%
#    🧪 真値: 89.54%
#    ❗ 誤差: -23.06%
#    🎯 獲得関数: 0.6539
#    🔄 モデル更新中... (学習データ数: 20)
#    💡 現在の最高収率: 96.12%
# ------------------------------------------------------------
# 獲得関数値を計算中... (1498個の候補)
# 🎯 選択: ('Brc1ccc(-c2ccccc2)cc1', 'COc1ccccc1C1=C(P(C2CCCCC2)C2CCCCC2)C2c3ccccc3C1c1ccccc12.OB(O)B(O)O.CCO') (EI: 0.7591)
# 🔎 Trial 21: Brc1ccc(-c2ccccc2)cc1 + COc1ccccc1C1=C(P(C2CCCCC2)C2CCCCC2)C2c3ccccc3C1c1ccccc12.OB(O)B(O)O.CCO → OB(O)c1ccc(-c2ccccc2)cc1
#    📈 予測: 67.63% ± 20.44%
#    🧪 真値: 93.78%
#    ❗ 誤差: -26.15%
#    🎯 獲得関数: 0.7591
#    🔄 モデル更新中... (学習データ数: 21)
#    💡 現在の最高収率: 96.12%
# ------------------------------------------------------------
# 獲得関数値を計算中... (1497個の候補)
# 🎯 選択: ('Brc1ccc(-c2ccccc2)cc1', 'COc1ccccc1C1=C(P(C2CCCCC2)C2CCCCC2)C2c3ccccc3C1c1ccccc12.OB(O)B(O)O.CO') (EI: 0.9116)
# 🔎 Trial 22: Brc1ccc(-c2ccccc2)cc1 + COc1ccccc1C1=C(P(C2CCCCC2)C2CCCCC2)C2c3ccccc3C1c1ccccc12.OB(O)B(O)O.CO → OB(O)c1ccc(-c2ccccc2)cc1
#    📈 予測: 68.87% ± 20.71%
#    🧪 真値: 83.20%
#    ❗ 誤差: -14.33%
#    🎯 獲得関数: 0.9116
#    🔄 モデル更新中... (学習データ数: 22)
#    💡 現在の最高収率: 96.12%
# ------------------------------------------------------------
# 獲得関数値を計算中... (1496個の候補)
# 🎯 選択: ('Brc1ccc(-c2ccccc2)cc1', 'COc1ccccc1P(c1ccccc1OC)c1ccccc1OC.OB(O)B(O)O.CCO') (EI: 0.9302)
# 🔎 Trial 23: Brc1ccc(-c2ccccc2)cc1 + COc1ccccc1P(c1ccccc1OC)c1ccccc1OC.OB(O)B(O)O.CCO → OB(O)c1ccc(-c2ccccc2)cc1
#    📈 予測: 69.52% ± 20.46%
#    🧪 真値: 78.00%
#    ❗ 誤差: -8.47%
#    🎯 獲得関数: 0.9302
#    🔄 モデル更新中... (学習データ数: 23)
#    💡 現在の最高収率: 96.12%
# ------------------------------------------------------------
# 獲得関数値を計算中... (1495個の候補)
# 🎯 選択: ('Brc1ccc(-c2ccccc2)cc1', 'COc1ccccc1P(c1ccccc1OC)c1ccccc1OC.OB(O)B(O)O.CO') (EI: 0.9017)
# 🔎 Trial 24: Brc1ccc(-c2ccccc2)cc1 + COc1ccccc1P(c1ccccc1OC)c1ccccc1OC.OB(O)B(O)O.CO → OB(O)c1ccc(-c2ccccc2)cc1
#    📈 予測: 69.89% ± 20.08%
#    🧪 真値: 77.98%
#    ❗ 誤差: -8.09%
#    🎯 獲得関数: 0.9017
#    🔄 モデル更新中... (学習データ数: 24)
#    💡 現在の最高収率: 96.12%
# ------------------------------------------------------------
# 獲得関数値を計算中... (1494個の候補)
# 🎯 選択: ('Brc1ccc(-c2ccccc2)cc1', 'C[PH+](C)C.F[B-](F)(F)F.OB(O)B(O)O.CCO') (EI: 0.8734)
# 🔎 Trial 25: Brc1ccc(-c2ccccc2)cc1 + C[PH+](C)C.F[B-](F)(F)F.OB(O)B(O)O.CCO → OB(O)c1ccc(-c2ccccc2)cc1
#    📈 予測: 70.23% ± 19.73%
#    🧪 真値: 36.81%
#    ❗ 誤差: +33.42%
#    🎯 獲得関数: 0.8734
#    🔄 モデル更新中... (学習データ数: 25)
#    💡 現在の最高収率: 96.12%
# ------------------------------------------------------------
# 獲得関数値を計算中... (1493個の候補)
# 🎯 選択: ('Brc1ccc(-c2ccccc2)cc1', 'C[PH+](C)C.F[B-](F)(F)F.OB(O)B(O)O.CO') (EI: 0.8628)
# 🔎 Trial 26: Brc1ccc(-c2ccccc2)cc1 + C[PH+](C)C.F[B-](F)(F)F.OB(O)B(O)O.CO → OB(O)c1ccc(-c2ccccc2)cc1
#    📈 予測: 68.89% ± 20.41%
#    🧪 真値: 42.34%
#    ❗ 誤差: +26.56%
#    🎯 獲得関数: 0.8628
#    🔄 モデル更新中... (学習データ数: 26)
#    💡 現在の最高収率: 96.12%
# ------------------------------------------------------------
# 獲得関数値を計算中... (1492個の候補)
# 🎯 選択: ('Brc1ccc(-c2ccccc2)cc1', 'Cc1cc(C)cc(P(c2cc(C)cc(C)c2)c2cc(C)cc(C)c2)c1.OB(O)B(O)O.CCO') (EI: 0.8120)
# 🔎 Trial 27: Brc1ccc(-c2ccccc2)cc1 + Cc1cc(C)cc(P(c2cc(C)cc(C)c2)c2cc(C)cc(C)c2)c1.OB(O)B(O)O.CCO → OB(O)c1ccc(-c2ccccc2)cc1
#    📈 予測: 67.87% ± 20.66%
#    🧪 真値: 93.50%
#    ❗ 誤差: -25.63%
#    🎯 獲得関数: 0.8120
#    🔄 モデル更新中... (学習データ数: 27)
#    💡 現在の最高収率: 96.12%
# ------------------------------------------------------------
# 獲得関数値を計算中... (1491個の候補)
# 🎯 選択: ('Brc1ccc(-c2ccccc2)cc1', 'Cc1cc(C)cc(P(c2cc(C)cc(C)c2)c2cc(C)cc(C)c2)c1.OB(O)B(O)O.CO') (EI: 0.9279)
# 🔎 Trial 28: Brc1ccc(-c2ccccc2)cc1 + Cc1cc(C)cc(P(c2cc(C)cc(C)c2)c2cc(C)cc(C)c2)c1.OB(O)B(O)O.CO → OB(O)c1ccc(-c2ccccc2)cc1
#    📈 予測: 68.82% ± 20.84%
#    🧪 真値: 68.12%
#    ❗ 誤差: +0.70%
#    🎯 獲得関数: 0.9279
#    🔄 モデル更新中... (学習データ数: 28)
#    💡 現在の最高収率: 96.12%
# ------------------------------------------------------------
# 獲得関数値を計算中... (1490個の候補)
# 🎯 選択: ('Brc1ccc(-c2ccccc2)cc1', 'Cc1ccccc1-c1ccccc1P(C1CCCCC1)C1CCCCC1.OB(O)B(O)O.CCO') (EI: 0.8632)
# 🔎 Trial 29: Brc1ccc(-c2ccccc2)cc1 + Cc1ccccc1-c1ccccc1P(C1CCCCC1)C1CCCCC1.OB(O)B(O)O.CCO → OB(O)c1ccc(-c2ccccc2)cc1
#    📈 予測: 68.79% ± 20.47%
#    🧪 真値: 82.87%
#    ❗ 誤差: -14.08%
#    🎯 獲得関数: 0.8632
#    🔄 モデル更新中... (学習データ数: 29)
#    💡 現在の最高収率: 96.12%
# ------------------------------------------------------------
# 獲得関数値を計算中... (1489個の候補)
# 🎯 選択: ('Brc1ccc(-c2ccccc2)cc1', 'Cc1ccccc1-c1ccccc1P(C1CCCCC1)C1CCCCC1.OB(O)B(O)O.CO') (EI: 0.8760)
# 🔎 Trial 30: Brc1ccc(-c2ccccc2)cc1 + Cc1ccccc1-c1ccccc1P(C1CCCCC1)C1CCCCC1.OB(O)B(O)O.CO → OB(O)c1ccc(-c2ccccc2)cc1
#    📈 予測: 69.28% ± 20.27%
#    🧪 真値: 82.73%
#    ❗ 誤差: -13.45%
#    🎯 獲得関数: 0.8760
#    🔄 モデル更新中... (学習データ数: 30)
#    💡 現在の最高収率: 96.12%
# ------------------------------------------------------------
# 獲得関数値を計算中... (1488個の候補)
# 🎯 選択: ('Brc1ccc(-c2ccccc2)cc1', 'Fc1ccc(P(c2ccc(F)cc2)c2ccc(F)cc2)cc1.OB(O)B(O)O.CCO') (EI: 0.8854)
# 🔎 Trial 31: Brc1ccc(-c2ccccc2)cc1 + Fc1ccc(P(c2ccc(F)cc2)c2ccc(F)cc2)cc1.OB(O)B(O)O.CCO → OB(O)c1ccc(-c2ccccc2)cc1
#    📈 予測: 69.73% ± 20.08%
#    🧪 真値: 100.00%
#    ❗ 誤差: -30.27%
#    🎯 獲得関数: 0.8854
#    🔄 モデル更新中... (学習データ数: 31)
#    💡 現在の最高収率: 100.00%
# ------------------------------------------------------------
# 獲得関数値を計算中... (1487個の候補)
# 🎯 選択: ('Brc1ccc(-c2ccccc2)cc1', 'Fc1ccc(P(c2ccc(F)cc2)c2ccc(F)cc2)cc1.OB(O)B(O)O.CO') (EI: 0.6990)
# 🔎 Trial 32: Brc1ccc(-c2ccccc2)cc1 + Fc1ccc(P(c2ccc(F)cc2)c2ccc(F)cc2)cc1.OB(O)B(O)O.CO → OB(O)c1ccc(-c2ccccc2)cc1
#    📈 予測: 70.70% ± 20.46%
#    🧪 真値: 88.63%
#    ❗ 誤差: -17.92%
#    🎯 獲得関数: 0.6990
#    🔄 モデル更新中... (学習データ数: 32)
#    💡 現在の最高収率: 100.00%
# ------------------------------------------------------------
# 獲得関数値を計算中... (1486個の候補)
# 🎯 選択: ('Brc1ccc(-c2ccccc2)cc1', 'c1ccc(-c2cc3ccccc3n2P(C2CCCCC2)C2CCCCC2)cc1.OB(O)B(O)O.CCO') (EI: 0.7306)
# 🔎 Trial 33: Brc1ccc(-c2ccccc2)cc1 + c1ccc(-c2cc3ccccc3n2P(C2CCCCC2)C2CCCCC2)cc1.OB(O)B(O)O.CCO → OB(O)c1ccc(-c2ccccc2)cc1
#    📈 予測: 71.26% ± 20.38%
#    🧪 真値: 80.58%
#    ❗ 誤差: -9.32%
#    🎯 獲得関数: 0.7306
#    🔄 モデル更新中... (学習データ数: 33)
#    💡 現在の最高収率: 100.00%
# ------------------------------------------------------------
# 獲得関数値を計算中... (1485個の候補)
# 🎯 選択: ('Brc1ccc(-c2ccccc2)cc1', 'c1ccc(-c2cc3ccccc3n2P(C2CCCCC2)C2CCCCC2)cc1.OB(O)B(O)O.CO') (EI: 0.7164)
# 🔎 Trial 34: Brc1ccc(-c2ccccc2)cc1 + c1ccc(-c2cc3ccccc3n2P(C2CCCCC2)C2CCCCC2)cc1.OB(O)B(O)O.CO → OB(O)c1ccc(-c2ccccc2)cc1
#    📈 予測: 71.55% ± 20.13%
#    🧪 真値: 87.80%
#    ❗ 誤差: -16.26%
#    🎯 獲得関数: 0.7164
#    🔄 モデル更新中... (学習データ数: 34)
#    💡 現在の最高収率: 100.00%
# ------------------------------------------------------------
# 獲得関数値を計算中... (1484個の候補)
# 🎯 選択: ('Brc1ccc(-c2ccccc2)cc1', 'c1ccc(-c2ccccc2P(C2CCCCC2)C2CCCCC2)cc1.OB(O)B(O)O.CCO') (EI: 0.7385)
# 🔎 Trial 35: Brc1ccc(-c2ccccc2)cc1 + c1ccc(-c2ccccc2P(C2CCCCC2)C2CCCCC2)cc1.OB(O)B(O)O.CCO → OB(O)c1ccc(-c2ccccc2)cc1
#    📈 予測: 72.03% ± 20.03%
#    🧪 真値: 94.18%
#    ❗ 誤差: -22.16%
#    🎯 獲得関数: 0.7385
#    🔄 モデル更新中... (学習データ数: 35)
#    💡 現在の最高収率: 100.00%
# ------------------------------------------------------------
# 獲得関数値を計算中... (1483個の候補)
# 🎯 選択: ('Brc1ccc(-c2ccccc2)cc1', 'c1ccc(-c2ccccc2P(C2CCCCC2)C2CCCCC2)cc1.OB(O)B(O)O.CO') (EI: 0.8000)
# 🔎 Trial 36: Brc1ccc(-c2ccccc2)cc1 + c1ccc(-c2ccccc2P(C2CCCCC2)C2CCCCC2)cc1.OB(O)B(O)O.CO → OB(O)c1ccc(-c2ccccc2)cc1
#    📈 予測: 72.66% ± 20.08%
#    🧪 真値: 94.78%
#    ❗ 誤差: -22.12%
#    🎯 獲得関数: 0.8000
#    🔄 モデル更新中... (学習データ数: 36)
#    💡 現在の最高収率: 100.00%
# ------------------------------------------------------------
# 獲得関数値を計算中... (1482個の候補)
# 🎯 選択: ('Brc1ccc(-c2ccccc2)cc1', 'c1ccc(-c2nn(-c3ccccc3)c(-c3ccccc3)c2-n2nccc2P(C2CCCCC2)C2CCCCC2)cc1.OB(O)B(O)O.CCO') (EI: 0.8630)
# 🔎 Trial 37: Brc1ccc(-c2ccccc2)cc1 + c1ccc(-c2nn(-c3ccccc3)c(-c3ccccc3)c2-n2nccc2P(C2CCCCC2)C2CCCCC2)cc1.OB(O)B(O)O.CCO → OB(O)c1ccc(-c2ccccc2)cc1
#    📈 予測: 73.27% ± 20.13%
#    🧪 真値: 86.30%
#    ❗ 誤差: -13.03%
#    🎯 獲得関数: 0.8630
#    🔄 モデル更新中... (学習データ数: 37)
#    💡 現在の最高収率: 100.00%
# ------------------------------------------------------------
# 獲得関数値を計算中... (1481個の候補)
# 🎯 選択: ('Brc1ccc(-c2ccccc2)cc1', 'c1ccc(-c2nn(-c3ccccc3)c(-c3ccccc3)c2-n2nccc2P(C2CCCCC2)C2CCCCC2)cc1.OB(O)B(O)O.CO') (EI: 0.8689)
# 🔎 Trial 38: Brc1ccc(-c2ccccc2)cc1 + c1ccc(-c2nn(-c3ccccc3)c(-c3ccccc3)c2-n2nccc2P(C2CCCCC2)C2CCCCC2)cc1.OB(O)B(O)O.CO → OB(O)c1ccc(-c2ccccc2)cc1
#    📈 予測: 73.62% ± 19.97%
#    🧪 真値: 94.40%
#    ❗ 誤差: -20.77%
#    🎯 獲得関数: 0.8689
#    🔄 モデル更新中... (学習データ数: 38)
#    💡 現在の最高収率: 100.00%
# ------------------------------------------------------------
# 獲得関数値を計算中... (1480個の候補)
# 🎯 選択: ('Brc1ccc(-c2ccccc2)cc1', 'c1ccc(-n2cccc2P(C2CCCCC2)C2CCCCC2)cc1.OB(O)B(O)O.CCO') (EI: 0.9236)
# 🔎 Trial 39: Brc1ccc(-c2ccccc2)cc1 + c1ccc(-n2cccc2P(C2CCCCC2)C2CCCCC2)cc1.OB(O)B(O)O.CCO → OB(O)c1ccc(-c2ccccc2)cc1
#    📈 予測: 74.17% ± 19.98%
#    🧪 真値: 92.16%
#    ❗ 誤差: -17.99%
#    🎯 獲得関数: 0.9236
#    🔄 モデル更新中... (学習データ数: 39)
#    💡 現在の最高収率: 100.00%
# ------------------------------------------------------------
# 獲得関数値を計算中... (1479個の候補)
# 🎯 選択: ('Brc1ccc(-c2ccccc2)cc1', 'c1ccc(-n2cccc2P(C2CCCCC2)C2CCCCC2)cc1.OB(O)B(O)O.CO') (EI: 0.9602)
# 🔎 Trial 40: Brc1ccc(-c2ccccc2)cc1 + c1ccc(-n2cccc2P(C2CCCCC2)C2CCCCC2)cc1.OB(O)B(O)O.CO → OB(O)c1ccc(-c2ccccc2)cc1
#    📈 予測: 74.63% ± 19.93%
#    🧪 真値: 91.01%
#    ❗ 誤差: -16.37%
#    🎯 獲得関数: 0.9602
#    🔄 モデル更新中... (学習データ数: 40)
#    💡 現在の最高収率: 100.00%
# ------------------------------------------------------------
# 獲得関数値を計算中... (1478個の候補)
# 🎯 選択: ('Brc1ccc(-c2ccccc2)cc1', 'c1ccc(P(C2CCCCC2)C2CCCCC2)c(-n2c3ccccc3c3ccccc32)c1.OB(O)B(O)O.CCO') (EI: 0.9871)
# 🔎 Trial 41: Brc1ccc(-c2ccccc2)cc1 + c1ccc(P(C2CCCCC2)C2CCCCC2)c(-n2c3ccccc3c3ccccc32)c1.OB(O)B(O)O.CCO → OB(O)c1ccc(-c2ccccc2)cc1
#    📈 予測: 75.04% ± 19.85%
#    🧪 真値: 83.66%
#    ❗ 誤差: -8.62%
#    🎯 獲得関数: 0.9871
#    🔄 モデル更新中... (学習データ数: 41)
#    💡 現在の最高収率: 100.00%
# ------------------------------------------------------------
# 獲得関数値を計算中... (1477個の候補)
# 🎯 選択: ('Brc1ccc(-c2ccccc2)cc1', 'c1ccc(P(C2CCCCC2)C2CCCCC2)c(-n2c3ccccc3c3ccccc32)c1.OB(O)B(O)O.CO') (EI: 0.9731)
# 🔎 Trial 42: Brc1ccc(-c2ccccc2)cc1 + c1ccc(P(C2CCCCC2)C2CCCCC2)c(-n2c3ccccc3c3ccccc32)c1.OB(O)B(O)O.CO → OB(O)c1ccc(-c2ccccc2)cc1
#    📈 予測: 75.25% ± 19.65%
#    🧪 真値: 89.10%
#    ❗ 誤差: -13.84%
#    🎯 獲得関数: 0.9731
#    🔄 モデル更新中... (学習データ数: 42)
#    💡 現在の最高収率: 100.00%
# ------------------------------------------------------------
# 獲得関数値を計算中... (1476個の候補)
# 🎯 選択: ('Brc1ccc(-c2ccccc2)cc1', 'c1ccc(P(c2ccccc2)C2CCCCC2)cc1.OB(O)B(O)O.CCO') (EI: 0.9857)
# 🔎 Trial 43: Brc1ccc(-c2ccccc2)cc1 + c1ccc(P(c2ccccc2)C2CCCCC2)cc1.OB(O)B(O)O.CCO → OB(O)c1ccc(-c2ccccc2)cc1
#    📈 予測: 75.58% ± 19.53%
#    🧪 真値: 98.36%
#    ❗ 誤差: -22.78%
#    🎯 獲得関数: 0.9857
#    🔄 モデル更新中... (学習データ数: 43)
#    💡 現在の最高収率: 100.00%
# ------------------------------------------------------------
# 獲得関数値を計算中... (1475個の候補)
# 🎯 選択: ('Brc1ccc(-c2ccccc2)cc1', 'c1ccc(P(c2ccccc2)C2CCCCC2)cc1.OB(O)B(O)O.CO') (EI: 1.0571)
# 🔎 Trial 44: Brc1ccc(-c2ccccc2)cc1 + c1ccc(P(c2ccccc2)C2CCCCC2)cc1.OB(O)B(O)O.CO → OB(O)c1ccc(-c2ccccc2)cc1
#    📈 予測: 76.11% ± 19.60%
#    🧪 真値: 83.41%
#    ❗ 誤差: -7.30%
#    🎯 獲得関数: 1.0571
#    🔄 モデル更新中... (学習データ数: 44)
#    💡 現在の最高収率: 100.00%
# ------------------------------------------------------------
# 獲得関数値を計算中... (1474個の候補)
# 🎯 選択: ('Brc1ccc(-c2ccccc2)cc1', 'c1ccc(P(c2ccccc2)c2ccccc2)cc1.OB(O)B(O)O.CCO') (EI: 1.0389)
# 🔎 Trial 45: Brc1ccc(-c2ccccc2)cc1 + c1ccc(P(c2ccccc2)c2ccccc2)cc1.OB(O)B(O)O.CCO → OB(O)c1ccc(-c2ccccc2)cc1
#    📈 予測: 76.28% ± 19.41%
#    🧪 真値: 96.01%
#    ❗ 誤差: -19.73%
#    🎯 獲得関数: 1.0389
#    🔄 モデル更新中... (学習データ数: 45)
#    💡 現在の最高収率: 100.00%
# ------------------------------------------------------------
# 獲得関数値を計算中... (1473個の候補)
# 🎯 選択: ('Brc1ccc(-c2ccccc2)cc1', 'c1ccc(P(c2ccccc2)c2ccccc2)cc1.OB(O)B(O)O.CO') (EI: 1.0889)
# 🔎 Trial 46: Brc1ccc(-c2ccccc2)cc1 + c1ccc(P(c2ccccc2)c2ccccc2)cc1.OB(O)B(O)O.CO → OB(O)c1ccc(-c2ccccc2)cc1
#    📈 予測: 76.72% ± 19.41%
#    🧪 真値: 81.26%
#    ❗ 誤差: -4.54%
#    🎯 獲得関数: 1.0889
#    🔄 モデル更新中... (学習データ数: 46)
#    💡 現在の最高収率: 100.00%
# ------------------------------------------------------------
# 獲得関数値を計算中... (1472個の候補)
# 🎯 選択: ('Brc1ccc2c(c1)OCO2', 'C1CCC([PH+](C2CCCCC2)C2CCCCC2)CC1.F[B-](F)(F)F.OB(O)B(O)O.CCO') (EI: 1.0614)
# 🔎 Trial 47: Brc1ccc2c(c1)OCO2 + C1CCC([PH+](C2CCCCC2)C2CCCCC2)CC1.F[B-](F)(F)F.OB(O)B(O)O.CCO → OB(O)c1ccc2c(c1)OCO2
#    📈 予測: 76.82% ± 19.21%
#    🧪 真値: 7.41%
#    ❗ 誤差: +69.41%
#    🎯 獲得関数: 1.0614
#    🔄 モデル更新中... (学習データ数: 47)
#    💡 現在の最高収率: 100.00%
# ------------------------------------------------------------
# 獲得関数値を計算中... (1471個の候補)
# 🎯 選択: ('Brc1ccc2c(c1)OCO2', 'C1CCC([PH+](C2CCCCC2)C2CCCCC2)CC1.F[B-](F)(F)F.OB(O)B(O)O.CO') (EI: 1.3392)
# 🔎 Trial 48: Brc1ccc2c(c1)OCO2 + C1CCC([PH+](C2CCCCC2)C2CCCCC2)CC1.F[B-](F)(F)F.OB(O)B(O)O.CO → OB(O)c1ccc2c(c1)OCO2
#    📈 予測: 75.34% ± 21.49%
#    🧪 真値: 30.04%
#    ❗ 誤差: +45.30%
#    🎯 獲得関数: 1.3392
#    🔄 モデル更新中... (学習データ数: 48)
#    💡 現在の最高収率: 100.00%
# ------------------------------------------------------------
# 獲得関数値を計算中... (1470個の候補)
# 🎯 選択: ('Brc1ccc2c(c1)OCO2', 'CC(=C(c1ccccc1)c1ccccc1)P(C1CCCCC1)C1CCCCC1.OB(O)B(O)O.CCO') (EI: 1.3734)
# 🔎 Trial 49: Brc1ccc2c(c1)OCO2 + CC(=C(c1ccccc1)c1ccccc1)P(C1CCCCC1)C1CCCCC1.OB(O)B(O)O.CCO → OB(O)c1ccc2c(c1)OCO2
#    📈 予測: 74.39% ± 22.23%
#    🧪 真値: 42.40%
#    ❗ 誤差: +31.99%
#    🎯 獲得関数: 1.3734
#    🔄 モデル更新中... (学習データ数: 49)
#    💡 現在の最高収率: 100.00%
# ------------------------------------------------------------
# 獲得関数値を計算中... (1469個の候補)
# 🎯 選択: ('Brc1ccc2c(c1)OCO2', 'CC(=C(c1ccccc1)c1ccccc1)P(C1CCCCC1)C1CCCCC1.OB(O)B(O)O.CO') (EI: 1.3407)
# 🔎 Trial 50: Brc1ccc2c(c1)OCO2 + CC(=C(c1ccccc1)c1ccccc1)P(C1CCCCC1)C1CCCCC1.OB(O)B(O)O.CO → OB(O)c1ccc2c(c1)OCO2
#    📈 予測: 73.74% ± 22.46%
#    🧪 真値: 51.62%
#    ❗ 誤差: +22.12%
#    🎯 獲得関数: 1.3407
#    🔄 モデル更新中... (学習データ数: 50)
#    💡 現在の最高収率: 100.00%
# ------------------------------------------------------------
# 獲得関数値を計算中... (1468個の候補)
# 🎯 選択: ('Brc1ccc2c(c1)OCO2', 'CC(C)(C)P(c1ccccc1)C(C)(C)C.OB(O)B(O)O.CCO') (EI: 1.2859)
# 🔎 Trial 51: Brc1ccc2c(c1)OCO2 + CC(C)(C)P(c1ccccc1)C(C)(C)C.OB(O)B(O)O.CCO → OB(O)c1ccc2c(c1)OCO2
#    📈 予測: 73.30% ± 22.45%
#    🧪 真値: 19.83%
#    ❗ 誤差: +53.47%
#    🎯 獲得関数: 1.2859
#    🔄 モデル更新中... (学習データ数: 51)
#    💡 現在の最高収率: 100.00%
# ------------------------------------------------------------
# 獲得関数値を計算中... (1467個の候補)
# 🎯 選択: ('Brc1ccc2c(c1)OCO2', 'CC(C)(C)P(c1ccccc1)C(C)(C)C.OB(O)B(O)O.CO') (EI: 1.3567)
# 🔎 Trial 52: Brc1ccc2c(c1)OCO2 + CC(C)(C)P(c1ccccc1)C(C)(C)C.OB(O)B(O)O.CO → OB(O)c1ccc2c(c1)OCO2
#    📈 予測: 72.25% ± 23.43%
#    🧪 真値: 19.39%
#    ❗ 誤差: +52.86%
#    🎯 獲得関数: 1.3567
#    🔄 モデル更新中... (学習データ数: 52)
#    💡 現在の最高収率: 100.00%
# ------------------------------------------------------------
# 獲得関数値を計算中... (1466個の候補)
# 🎯 選択: ('Brc1ccc2c(c1)OCO2', 'CC(C)c1cc(C(C)C)c(-c2ccccc2P(c2ccccc2)c2ccccc2)c(C(C)C)c1.OB(O)B(O)O.CCO') (EI: 1.4117)
# 🔎 Trial 53: Brc1ccc2c(c1)OCO2 + CC(C)c1cc(C(C)C)c(-c2ccccc2P(c2ccccc2)c2ccccc2)c(C(C)C)c1.OB(O)B(O)O.CCO → OB(O)c1ccc2c(c1)OCO2
#    📈 予測: 71.23% ± 24.32%
#    🧪 真値: 37.01%
#    ❗ 誤差: +34.22%
#    🎯 獲得関数: 1.4117
#    🔄 モデル更新中... (学習データ数: 53)
#    💡 現在の最高収率: 100.00%
# ------------------------------------------------------------
# 獲得関数値を計算中... (1465個の候補)
# 🎯 選択: ('Brc1ccc2c(c1)OCO2', 'CC(C)c1cc(C(C)C)c(-c2ccccc2P(c2ccccc2)c2ccccc2)c(C(C)C)c1.OB(O)B(O)O.CO') (EI: 1.3787)
# 🔎 Trial 54: Brc1ccc2c(c1)OCO2 + CC(C)c1cc(C(C)C)c(-c2ccccc2P(c2ccccc2)c2ccccc2)c(C(C)C)c1.OB(O)B(O)O.CO → OB(O)c1ccc2c(c1)OCO2
#    📈 予測: 70.59% ± 24.53%
#    🧪 真値: 34.70%
#    ❗ 誤差: +35.89%
#    🎯 獲得関数: 1.3787
#    🔄 モデル更新中... (学習データ数: 54)
#    💡 現在の最高収率: 100.00%
# ------------------------------------------------------------
# 獲得関数値を計算中... (1464個の候補)
# 🎯 選択: ('Brc1ccc2c(c1)OCO2', 'CCCCC1([PH+](C2CCCCC2)C2CCCCC2)c2ccccc2-c2ccccc21.F[B-](F)(F)F.OB(O)B(O)O.CCO') (EI: 1.3511)
# 🔎 Trial 55: Brc1ccc2c(c1)OCO2 + CCCCC1([PH+](C2CCCCC2)C2CCCCC2)c2ccccc2-c2ccccc21.F[B-](F)(F)F.OB(O)B(O)O.CCO → OB(O)c1ccc2c(c1)OCO2
#    📈 予測: 69.92% ± 24.78%
#    🧪 真値: 25.08%
#    ❗ 誤差: +44.84%
#    🎯 獲得関数: 1.3511
#    🔄 モデル更新中... (学習データ数: 55)
#    💡 現在の最高収率: 100.00%
# ------------------------------------------------------------
# 獲得関数値を計算中... (1463個の候補)
# 🎯 選択: ('Brc1ccc2c(c1)OCO2', 'CCCCC1([PH+](C2CCCCC2)C2CCCCC2)c2ccccc2-c2ccccc21.F[B-](F)(F)F.OB(O)B(O)O.CO') (EI: 1.3543)
# 🔎 Trial 56: Brc1ccc2c(c1)OCO2 + CCCCC1([PH+](C2CCCCC2)C2CCCCC2)c2ccccc2-c2ccccc21.F[B-](F)(F)F.OB(O)B(O)O.CO → OB(O)c1ccc2c(c1)OCO2
#    📈 予測: 69.11% ± 25.28%
#    🧪 真値: 38.52%
#    ❗ 誤差: +30.59%
#    🎯 獲得関数: 1.3543
#    🔄 モデル更新中... (学習データ数: 56)
#    💡 現在の最高収率: 100.00%
# ------------------------------------------------------------
# 獲得関数値を計算中... (1462個の候補)
# 🎯 選択: ('Brc1ccc2c(c1)OCO2', 'CN(C)c1ccc(P(c2ccccc2)c2ccccc2)cc1.OB(O)B(O)O.CCO') (EI: 1.3132)
# 🔎 Trial 57: Brc1ccc2c(c1)OCO2 + CN(C)c1ccc(P(c2ccccc2)c2ccccc2)cc1.OB(O)B(O)O.CCO → OB(O)c1ccc2c(c1)OCO2
#    📈 予測: 68.56% ± 25.38%
#    🧪 真値: 64.84%
#    ❗ 誤差: +3.72%
#    🎯 獲得関数: 1.3132
#    🔄 モデル更新中... (学習データ数: 57)
#    💡 現在の最高収率: 100.00%
# ------------------------------------------------------------
# 獲得関数値を計算中... (1461個の候補)
# 🎯 選択: ('Brc1ccc2c(c1)OCO2', 'CN(C)c1ccc(P(c2ccccc2)c2ccccc2)cc1.OB(O)B(O)O.CO') (EI: 1.2660)
# 🔎 Trial 58: Brc1ccc2c(c1)OCO2 + CN(C)c1ccc(P(c2ccccc2)c2ccccc2)cc1.OB(O)B(O)O.CO → OB(O)c1ccc2c(c1)OCO2
#    📈 予測: 68.50% ± 25.16%
#    🧪 真値: 33.69%
#    ❗ 誤差: +34.81%
#    🎯 獲得関数: 1.2660
#    🔄 モデル更新中... (学習データ数: 58)
#    💡 現在の最高収率: 100.00%
# ------------------------------------------------------------
# 獲得関数値を計算中... (1460個の候補)
# 🎯 選択: ('Brc1ccc2c(c1)OCO2', 'CN(C)c1ccccc1-c1ccccc1P(c1ccccc1)c1ccccc1.OB(O)B(O)O.CCO') (EI: 1.2382)
# 🔎 Trial 59: Brc1ccc2c(c1)OCO2 + CN(C)c1ccccc1-c1ccccc1P(c1ccccc1)c1ccccc1.OB(O)B(O)O.CCO → OB(O)c1ccc2c(c1)OCO2
#    📈 予測: 67.90% ± 25.35%
#    🧪 真値: 62.32%
#    ❗ 誤差: +5.58%
#    🎯 獲得関数: 1.2382
#    🔄 モデル更新中... (学習データ数: 59)
#    💡 現在の最高収率: 100.00%
# ------------------------------------------------------------
# 獲得関数値を計算中... (1459個の候補)
# 🎯 選択: ('Brc1ccc2c(c1)OCO2', 'CN(C)c1ccccc1-c1ccccc1P(c1ccccc1)c1ccccc1.OB(O)B(O)O.CO') (EI: 1.1922)
# 🔎 Trial 60: Brc1ccc2c(c1)OCO2 + CN(C)c1ccccc1-c1ccccc1P(c1ccccc1)c1ccccc1.OB(O)B(O)O.CO → OB(O)c1ccc2c(c1)OCO2
#    📈 予測: 67.80% ± 25.15%
#    🧪 真値: 67.09%
#    ❗ 誤差: +0.71%
#    🎯 獲得関数: 1.1922
#    🔄 モデル更新中... (学習データ数: 60)
#    💡 現在の最高収率: 100.00%
# ------------------------------------------------------------
# 獲得関数値を計算中... (1458個の候補)
# 🎯 選択: ('Brc1ccc2c(c1)OCO2', 'COc1cc(C(C)(C)C)cc(C(C)(C)C)c1-c1ccccc1P(C1CCCCC1)C1CCCCC1.OB(O)B(O)O.CCO') (EI: 1.1543)
# 🔎 Trial 61: Brc1ccc2c(c1)OCO2 + COc1cc(C(C)(C)C)cc(C(C)(C)C)c1-c1ccccc1P(C1CCCCC1)C1CCCCC1.OB(O)B(O)O.CCO → OB(O)c1ccc2c(c1)OCO2
#    📈 予測: 67.79% ± 24.93%
#    🧪 真値: 24.86%
#    ❗ 誤差: +42.93%
#    🎯 獲得関数: 1.1543
#    🔄 モデル更新中... (学習データ数: 61)
#    💡 現在の最高収率: 100.00%
# ------------------------------------------------------------
# 獲得関数値を計算中... (1457個の候補)
# 🎯 選択: ('Brc1ccc2c(c1)OCO2', 'COc1cc(C(C)(C)C)cc(C(C)(C)C)c1-c1ccccc1P(C1CCCCC1)C1CCCCC1.OB(O)B(O)O.CO') (EI: 1.1528)
# 🔎 Trial 62: Brc1ccc2c(c1)OCO2 + COc1cc(C(C)(C)C)cc(C(C)(C)C)c1-c1ccccc1P(C1CCCCC1)C1CCCCC1.OB(O)B(O)O.CO → OB(O)c1ccc2c(c1)OCO2
#    📈 予測: 67.09% ± 25.32%
#    🧪 真値: 42.03%
#    ❗ 誤差: +25.06%
#    🎯 獲得関数: 1.1528
#    🔄 モデル更新中... (学習データ数: 62)
#    💡 現在の最高収率: 100.00%
# ------------------------------------------------------------
# 獲得関数値を計算中... (1456個の候補)
# 🎯 選択: ('Brc1ccc2c(c1)OCO2', 'COc1ccc(P(c2ccc(OC)cc2)c2ccc(OC)cc2)cc1.OB(O)B(O)O.CCO') (EI: 1.1131)
# 🔎 Trial 63: Brc1ccc2c(c1)OCO2 + COc1ccc(P(c2ccc(OC)cc2)c2ccc(OC)cc2)cc1.OB(O)B(O)O.CCO → OB(O)c1ccc2c(c1)OCO2
#    📈 予測: 66.68% ± 25.32%
#    🧪 真値: 59.44%
#    ❗ 誤差: +7.24%
#    🎯 獲得関数: 1.1131
#    🔄 モデル更新中... (学習データ数: 63)
#    💡 現在の最高収率: 100.00%
# ------------------------------------------------------------
# 獲得関数値を計算中... (1455個の候補)
# 🎯 選択: ('Brc1ccc2c(c1)OCO2', 'COc1ccc(P(c2ccc(OC)cc2)c2ccc(OC)cc2)cc1.OB(O)B(O)O.CO') (EI: 1.0716)
# 🔎 Trial 64: Brc1ccc2c(c1)OCO2 + COc1ccc(P(c2ccc(OC)cc2)c2ccc(OC)cc2)cc1.OB(O)B(O)O.CO → OB(O)c1ccc2c(c1)OCO2
#    📈 予測: 66.57% ± 25.13%
#    🧪 真値: 30.69%
#    ❗ 誤差: +35.88%
#    🎯 獲得関数: 1.0716
#    🔄 モデル更新中... (学習データ数: 64)
#    💡 現在の最高収率: 100.00%
# ------------------------------------------------------------
# 獲得関数値を計算中... (1454個の候補)
# 🎯 選択: ('Brc1ccc2c(c1)OCO2', 'COc1cccc(OC)c1-c1ccccc1P(c1ccccc1)c1ccccc1.OB(O)B(O)O.CCO') (EI: 1.0530)
# 🔎 Trial 65: Brc1ccc2c(c1)OCO2 + COc1cccc(OC)c1-c1ccccc1P(c1ccccc1)c1ccccc1.OB(O)B(O)O.CCO → OB(O)c1ccc2c(c1)OCO2
#    📈 予測: 66.01% ± 25.33%
#    🧪 真値: 56.06%
#    ❗ 誤差: +9.95%
#    🎯 獲得関数: 1.0530
#    🔄 モデル更新中... (学習データ数: 65)
#    💡 現在の最高収率: 100.00%
# ------------------------------------------------------------
# 獲得関数値を計算中... (1453個の候補)
# 🎯 選択: ('Brc1ccc2c(c1)OCO2', 'COc1cccc(OC)c1-c1ccccc1P(c1ccccc1)c1ccccc1.OB(O)B(O)O.CO') (EI: 1.0129)
# 🔎 Trial 66: Brc1ccc2c(c1)OCO2 + COc1cccc(OC)c1-c1ccccc1P(c1ccccc1)c1ccccc1.OB(O)B(O)O.CO → OB(O)c1ccc2c(c1)OCO2
#    📈 予測: 65.85% ± 25.16%
#    🧪 真値: 60.34%
#    ❗ 誤差: +5.51%
#    🎯 獲得関数: 1.0129
#    🔄 モデル更新中... (学習データ数: 66)
#    💡 現在の最高収率: 100.00%
# ------------------------------------------------------------
# 獲得関数値を計算中... (1452個の候補)
# 🎯 選択: ('Brc1ccc2c(c1)OCO2', 'COc1ccccc1C1=C(P(C2CCCCC2)C2CCCCC2)C2c3ccccc3C1c1ccccc12.OB(O)B(O)O.CCO') (EI: 0.9770)
# 🔎 Trial 67: Brc1ccc2c(c1)OCO2 + COc1ccccc1C1=C(P(C2CCCCC2)C2CCCCC2)C2c3ccccc3C1c1ccccc12.OB(O)B(O)O.CCO → OB(O)c1ccc2c(c1)OCO2
#    📈 予測: 65.77% ± 24.98%
#    🧪 真値: 46.14%
#    ❗ 誤差: +19.63%
#    🎯 獲得関数: 0.9770
#    🔄 モデル更新中... (学習データ数: 67)
#    💡 現在の最高収率: 100.00%
# ------------------------------------------------------------
# 獲得関数値を計算中... (1451個の候補)
# 🎯 選択: ('Brc1ccc2c(c1)OCO2', 'COc1ccccc1C1=C(P(C2CCCCC2)C2CCCCC2)C2c3ccccc3C1c1ccccc12.OB(O)B(O)O.CO') (EI: 0.9411)
# 🔎 Trial 68: Brc1ccc2c(c1)OCO2 + COc1ccccc1C1=C(P(C2CCCCC2)C2CCCCC2)C2c3ccccc3C1c1ccccc12.OB(O)B(O)O.CO → OB(O)c1ccc2c(c1)OCO2
#    📈 予測: 65.48% ± 24.91%
#    🧪 真値: 76.76%
#    ❗ 誤差: -11.28%
#    🎯 獲得関数: 0.9411
#    🔄 モデル更新中... (学習データ数: 68)
#    💡 現在の最高収率: 100.00%
# ------------------------------------------------------------
# 獲得関数値を計算中... (1450個の候補)
# 🎯 選択: ('Brc1ccc2c(c1)OCO2', 'COc1ccccc1P(c1ccccc1OC)c1ccccc1OC.OB(O)B(O)O.CCO') (EI: 0.9325)
# 🔎 Trial 69: Brc1ccc2c(c1)OCO2 + COc1ccccc1P(c1ccccc1OC)c1ccccc1OC.OB(O)B(O)O.CCO → OB(O)c1ccc2c(c1)OCO2
#    📈 予測: 65.64% ± 24.76%
#    🧪 真値: 48.34%
#    ❗ 誤差: +17.30%
#    🎯 獲得関数: 0.9325
#    🔄 モデル更新中... (学習データ数: 69)
#    💡 現在の最高収率: 100.00%
# ------------------------------------------------------------
# 獲得関数値を計算中... (1449個の候補)
# 🎯 選択: ('Brc1ccc2c(c1)OCO2', 'COc1ccccc1P(c1ccccc1OC)c1ccccc1OC.OB(O)B(O)O.CO') (EI: 0.8980)
# 🔎 Trial 70: Brc1ccc2c(c1)OCO2 + COc1ccccc1P(c1ccccc1OC)c1ccccc1OC.OB(O)B(O)O.CO → OB(O)c1ccc2c(c1)OCO2
#    📈 予測: 65.39% ± 24.67%
#    🧪 真値: 57.07%
#    ❗ 誤差: +8.32%
#    🎯 獲得関数: 0.8980
#    🔄 モデル更新中... (学習データ数: 70)
#    💡 現在の最高収率: 100.00%
# ------------------------------------------------------------
# 獲得関数値を計算中... (1448個の候補)
# 🎯 選択: ('Brc1ccc2c(c1)OCO2', 'C[PH+](C)C.F[B-](F)(F)F.OB(O)B(O)O.CCO') (EI: 0.8654)
# 🔎 Trial 71: Brc1ccc2c(c1)OCO2 + C[PH+](C)C.F[B-](F)(F)F.OB(O)B(O)O.CCO → OB(O)c1ccc2c(c1)OCO2
#    📈 予測: 65.27% ± 24.51%
#    🧪 真値: 50.63%
#    ❗ 誤差: +14.64%
#    🎯 獲得関数: 0.8654
#    🔄 モデル更新中... (学習データ数: 71)
#    💡 現在の最高収率: 100.00%
# ------------------------------------------------------------
# 獲得関数値を計算中... (1447個の候補)
# 🎯 選択: ('Brc1ccc2c(c1)OCO2', 'C[PH+](C)C.F[B-](F)(F)F.OB(O)B(O)O.CO') (EI: 0.8333)
# 🔎 Trial 72: Brc1ccc2c(c1)OCO2 + C[PH+](C)C.F[B-](F)(F)F.OB(O)B(O)O.CO → OB(O)c1ccc2c(c1)OCO2
#    📈 予測: 65.07% ± 24.40%
#    🧪 真値: 38.58%
#    ❗ 誤差: +26.49%
#    🎯 獲得関数: 0.8333
#    🔄 モデル更新中... (学習データ数: 72)
#    💡 現在の最高収率: 100.00%
# ------------------------------------------------------------
# 獲得関数値を計算中... (1446個の候補)
# 🎯 選択: ('Brc1ccc2c(c1)OCO2', 'Cc1cc(C)cc(P(c2cc(C)cc(C)c2)c2cc(C)cc(C)c2)c1.OB(O)B(O)O.CCO') (EI: 0.8096)
# 🔎 Trial 73: Brc1ccc2c(c1)OCO2 + Cc1cc(C)cc(P(c2cc(C)cc(C)c2)c2cc(C)cc(C)c2)c1.OB(O)B(O)O.CCO → OB(O)c1ccc2c(c1)OCO2
#    📈 予測: 64.70% ± 24.43%
#    🧪 真値: 12.86%
#    ❗ 誤差: +51.84%
#    🎯 獲得関数: 0.8096
#    🔄 モデル更新中... (学習データ数: 73)
#    💡 現在の最高収率: 100.00%
# ------------------------------------------------------------
# 獲得関数値を計算中... (1445個の候補)
# 🎯 選択: ('Brc1ccc2c(c1)OCO2', 'Cc1cc(C)cc(P(c2cc(C)cc(C)c2)c2cc(C)cc(C)c2)c1.OB(O)B(O)O.CO') (EI: 0.8371)
# 🔎 Trial 74: Brc1ccc2c(c1)OCO2 + Cc1cc(C)cc(P(c2cc(C)cc(C)c2)c2cc(C)cc(C)c2)c1.OB(O)B(O)O.CO → OB(O)c1ccc2c(c1)OCO2
#    📈 予測: 63.99% ± 25.00%
#    🧪 真値: 32.08%
#    ❗ 誤差: +31.91%
#    🎯 獲得関数: 0.8371
#    🔄 モデル更新中... (学習データ数: 74)
#    💡 現在の最高収率: 100.00%
# ------------------------------------------------------------
# 獲得関数値を計算中... (1444個の候補)
# 🎯 選択: ('Brc1ccc2c(c1)OCO2', 'Cc1ccccc1-c1ccccc1P(C1CCCCC1)C1CCCCC1.OB(O)B(O)O.CCO') (EI: 0.8196)
# 🔎 Trial 75: Brc1ccc2c(c1)OCO2 + Cc1ccccc1-c1ccccc1P(C1CCCCC1)C1CCCCC1.OB(O)B(O)O.CCO → OB(O)c1ccc2c(c1)OCO2
#    📈 予測: 63.56% ± 25.10%
#    🧪 真値: 42.37%
#    ❗ 誤差: +21.19%
#    🎯 獲得関数: 0.8196
#    🔄 モデル更新中... (学習データ数: 75)
#    💡 現在の最高収率: 100.00%
# ------------------------------------------------------------
# 獲得関数値を計算中... (1443個の候補)
# 🎯 選択: ('Brc1ccc2c(c1)OCO2', 'Cc1ccccc1-c1ccccc1P(C1CCCCC1)C1CCCCC1.OB(O)B(O)O.CO') (EI: 0.7924)
# 🔎 Trial 76: Brc1ccc2c(c1)OCO2 + Cc1ccccc1-c1ccccc1P(C1CCCCC1)C1CCCCC1.OB(O)B(O)O.CO → OB(O)c1ccc2c(c1)OCO2
#    📈 予測: 63.28% ± 25.05%
#    🧪 真値: 63.45%
#    ❗ 誤差: -0.17%
#    🎯 獲得関数: 0.7924
#    🔄 モデル更新中... (学習データ数: 76)
#    💡 現在の最高収率: 100.00%
# ------------------------------------------------------------
# 獲得関数値を計算中... (1442個の候補)
# 🎯 選択: ('Brc1ccc2c(c1)OCO2', 'Fc1ccc(P(c2ccc(F)cc2)c2ccc(F)cc2)cc1.OB(O)B(O)O.CCO') (EI: 0.7702)
# 🔎 Trial 77: Brc1ccc2c(c1)OCO2 + Fc1ccc(P(c2ccc(F)cc2)c2ccc(F)cc2)cc1.OB(O)B(O)O.CCO → OB(O)c1ccc2c(c1)OCO2
#    📈 予測: 63.28% ± 24.89%
#    🧪 真値: 78.82%
#    ❗ 誤差: -15.54%
#    🎯 獲得関数: 0.7702
#    🔄 モデル更新中... (学習データ数: 77)
#    💡 現在の最高収率: 100.00%
# ------------------------------------------------------------
# 獲得関数値を計算中... (1441個の候補)
# 🎯 選択: ('Brc1ccc2c(c1)OCO2', 'Fc1ccc(P(c2ccc(F)cc2)c2ccc(F)cc2)cc1.OB(O)B(O)O.CO') (EI: 0.7709)
# 🔎 Trial 78: Brc1ccc2c(c1)OCO2 + Fc1ccc(P(c2ccc(F)cc2)c2ccc(F)cc2)cc1.OB(O)B(O)O.CO → OB(O)c1ccc2c(c1)OCO2
#    📈 予測: 63.48% ± 24.79%
#    🧪 真値: 85.78%
#    ❗ 誤差: -22.30%
#    🎯 獲得関数: 0.7709
#    🔄 モデル更新中... (学習データ数: 78)
#    💡 現在の最高収率: 100.00%
# ------------------------------------------------------------
# 獲得関数値を計算中... (1440個の候補)
# 🎯 選択: ('Brc1ccc2c(c1)OCO2', 'c1ccc(-c2cc3ccccc3n2P(C2CCCCC2)C2CCCCC2)cc1.OB(O)B(O)O.CCO') (EI: 0.7869)
# 🔎 Trial 79: Brc1ccc2c(c1)OCO2 + c1ccc(-c2cc3ccccc3n2P(C2CCCCC2)C2CCCCC2)cc1.OB(O)B(O)O.CCO → OB(O)c1ccc2c(c1)OCO2
#    📈 予測: 63.77% ± 24.75%
#    🧪 真値: 34.29%
#    ❗ 誤差: +29.48%
#    🎯 獲得関数: 0.7869
#    🔄 モデル更新中... (学習データ数: 79)
#    💡 現在の最高収率: 100.00%
# ------------------------------------------------------------
# 獲得関数値を計算中... (1439個の候補)
# 🎯 選択: ('Brc1ccc2c(c1)OCO2', 'c1ccc(-c2cc3ccccc3n2P(C2CCCCC2)C2CCCCC2)cc1.OB(O)B(O)O.CO') (EI: 0.7690)
# 🔎 Trial 80: Brc1ccc2c(c1)OCO2 + c1ccc(-c2cc3ccccc3n2P(C2CCCCC2)C2CCCCC2)cc1.OB(O)B(O)O.CO → OB(O)c1ccc2c(c1)OCO2
#    📈 予測: 63.39% ± 24.82%
#    🧪 真値: 81.89%
#    ❗ 誤差: -18.50%
#    🎯 獲得関数: 0.7690
#    🔄 モデル更新中... (学習データ数: 80)
#    💡 現在の最高収率: 100.00%
# ------------------------------------------------------------
# 獲得関数値を計算中... (1438個の候補)
# 🎯 選択: ('Brc1ccc2c(c1)OCO2', 'c1ccc(-c2ccccc2P(C2CCCCC2)C2CCCCC2)cc1.OB(O)B(O)O.CCO') (EI: 0.7759)
# 🔎 Trial 81: Brc1ccc2c(c1)OCO2 + c1ccc(-c2ccccc2P(C2CCCCC2)C2CCCCC2)cc1.OB(O)B(O)O.CCO → OB(O)c1ccc2c(c1)OCO2
#    📈 予測: 63.62% ± 24.75%
#    🧪 真値: 70.74%
#    ❗ 誤差: -7.12%
#    🎯 獲得関数: 0.7759
#    🔄 モデル更新中... (学習データ数: 81)
#    💡 現在の最高収率: 100.00%
# ------------------------------------------------------------
# 獲得関数値を計算中... (1437個の候補)
# 🎯 選択: ('Brc1ccc2c(c1)OCO2', 'c1ccc(-c2ccccc2P(C2CCCCC2)C2CCCCC2)cc1.OB(O)B(O)O.CO') (EI: 0.7631)
# 🔎 Trial 82: Brc1ccc2c(c1)OCO2 + c1ccc(-c2ccccc2P(C2CCCCC2)C2CCCCC2)cc1.OB(O)B(O)O.CO → OB(O)c1ccc2c(c1)OCO2
#    📈 予測: 63.71% ± 24.61%
#    🧪 真値: 100.00%
#    ❗ 誤差: -36.29%
#    🎯 獲得関数: 0.7631
#    🔄 モデル更新中... (学習データ数: 82)
#    💡 現在の最高収率: 100.00%
# ------------------------------------------------------------
# 獲得関数値を計算中... (1436個の候補)
# 🎯 選択: ('Brc1ccc2c(c1)OCO2', 'c1ccc(-c2nn(-c3ccccc3)c(-c3ccccc3)c2-n2nccc2P(C2CCCCC2)C2CCCCC2)cc1.OB(O)B(O)O.CCO') (EI: 0.8186)
# 🔎 Trial 83: Brc1ccc2c(c1)OCO2 + c1ccc(-c2nn(-c3ccccc3)c(-c3ccccc3)c2-n2nccc2P(C2CCCCC2)C2CCCCC2)cc1.OB(O)B(O)O.CCO → OB(O)c1ccc2c(c1)OCO2
#    📈 予測: 64.15% ± 24.78%
#    🧪 真値: 47.77%
#    ❗ 誤差: +16.38%
#    🎯 獲得関数: 0.8186
#    🔄 モデル更新中... (学習データ数: 83)
#    💡 現在の最高収率: 100.00%
# ------------------------------------------------------------
# 獲得関数値を計算中... (1435個の候補)
# 🎯 選択: ('Brc1ccc2c(c1)OCO2', 'c1ccc(-c2nn(-c3ccccc3)c(-c3ccccc3)c2-n2nccc2P(C2CCCCC2)C2CCCCC2)cc1.OB(O)B(O)O.CO') (EI: 0.7924)
# 🔎 Trial 84: Brc1ccc2c(c1)OCO2 + c1ccc(-c2nn(-c3ccccc3)c(-c3ccccc3)c2-n2nccc2P(C2CCCCC2)C2CCCCC2)cc1.OB(O)B(O)O.CO → OB(O)c1ccc2c(c1)OCO2
#    📈 予測: 63.96% ± 24.69%
#    🧪 真値: 95.19%
#    ❗ 誤差: -31.23%
#    🎯 獲得関数: 0.7924
#    🔄 モデル更新中... (学習データ数: 84)
#    💡 現在の最高収率: 100.00%
# ------------------------------------------------------------
# 獲得関数値を計算中... (1434個の候補)
# 🎯 選択: ('Brc1ccc2c(c1)OCO2', 'c1ccc(-n2cccc2P(C2CCCCC2)C2CCCCC2)cc1.OB(O)B(O)O.CCO') (EI: 0.8317)
# 🔎 Trial 85: Brc1ccc2c(c1)OCO2 + c1ccc(-n2cccc2P(C2CCCCC2)C2CCCCC2)cc1.OB(O)B(O)O.CCO → OB(O)c1ccc2c(c1)OCO2
#    📈 予測: 64.33% ± 24.78%
#    🧪 真値: 65.10%
#    ❗ 誤差: -0.77%
#    🎯 獲得関数: 0.8317
#    🔄 モデル更新中... (学習データ数: 85)
#    💡 現在の最高収率: 100.00%
# ------------------------------------------------------------
# 獲得関数値を計算中... (1433個の候補)
# 🎯 選択: ('Brc1ccc2c(c1)OCO2', 'c1ccc(-n2cccc2P(C2CCCCC2)C2CCCCC2)cc1.OB(O)B(O)O.CO') (EI: 0.8118)
# 🔎 Trial 86: Brc1ccc2c(c1)OCO2 + c1ccc(-n2cccc2P(C2CCCCC2)C2CCCCC2)cc1.OB(O)B(O)O.CO → OB(O)c1ccc2c(c1)OCO2
#    📈 予測: 64.34% ± 24.63%
#    🧪 真値: 88.24%
#    ❗ 誤差: -23.90%
#    🎯 獲得関数: 0.8118
#    🔄 モデル更新中... (学習データ数: 86)
#    💡 現在の最高収率: 100.00%
# ------------------------------------------------------------
# 獲得関数値を計算中... (1432個の候補)
# 🎯 選択: ('Brc1ccc2c(c1)OCO2', 'c1ccc(P(C2CCCCC2)C2CCCCC2)c(-n2c3ccccc3c3ccccc32)c1.OB(O)B(O)O.CCO') (EI: 0.8312)
# 🔎 Trial 87: Brc1ccc2c(c1)OCO2 + c1ccc(P(C2CCCCC2)C2CCCCC2)c(-n2c3ccccc3c3ccccc32)c1.OB(O)B(O)O.CCO → OB(O)c1ccc2c(c1)OCO2
#    📈 予測: 64.62% ± 24.62%
#    🧪 真値: 63.48%
#    ❗ 誤差: +1.14%
#    🎯 獲得関数: 0.8312
#    🔄 モデル更新中... (学習データ数: 87)
#    💡 現在の最高収率: 100.00%
# ------------------------------------------------------------
# 獲得関数値を計算中... (1431個の候補)
# 🎯 選択: ('Brc1ccc2c(c1)OCO2', 'c1ccc(P(C2CCCCC2)C2CCCCC2)c(-n2c3ccccc3c3ccccc32)c1.OB(O)B(O)O.CO') (EI: 0.8102)
# 🔎 Trial 88: Brc1ccc2c(c1)OCO2 + c1ccc(P(C2CCCCC2)C2CCCCC2)c(-n2c3ccccc3c3ccccc32)c1.OB(O)B(O)O.CO → OB(O)c1ccc2c(c1)OCO2
#    📈 予測: 64.60% ± 24.48%
#    🧪 真値: 82.93%
#    ❗ 誤差: -18.33%
#    🎯 獲得関数: 0.8102
#    🔄 モデル更新中... (学習データ数: 88)
#    💡 現在の最高収率: 100.00%
# ------------------------------------------------------------
# 獲得関数値を計算中... (1430個の候補)
# 🎯 選択: ('Brc1ccc2c(c1)OCO2', 'c1ccc(P(c2ccccc2)C2CCCCC2)cc1.OB(O)B(O)O.CCO') (EI: 0.8170)
# 🔎 Trial 89: Brc1ccc2c(c1)OCO2 + c1ccc(P(c2ccccc2)C2CCCCC2)cc1.OB(O)B(O)O.CCO → OB(O)c1ccc2c(c1)OCO2
#    📈 予測: 64.81% ± 24.42%
#    🧪 真値: 40.74%
#    ❗ 誤差: +24.07%
#    🎯 獲得関数: 0.8170
#    🔄 モデル更新中... (学習データ数: 89)
#    💡 現在の最高収率: 100.00%
# ------------------------------------------------------------
# 獲得関数値を計算中... (1429個の候補)
# 🎯 選択: ('Brc1ccc2c(c1)OCO2', 'c1ccc(P(c2ccccc2)C2CCCCC2)cc1.OB(O)B(O)O.CO') (EI: 0.7962)
# 🔎 Trial 90: Brc1ccc2c(c1)OCO2 + c1ccc(P(c2ccccc2)C2CCCCC2)cc1.OB(O)B(O)O.CO → OB(O)c1ccc2c(c1)OCO2
#    📈 予測: 64.54% ± 24.42%
#    🧪 真値: 37.54%
#    ❗ 誤差: +27.00%
#    🎯 獲得関数: 0.7962
#    🔄 モデル更新中... (学習データ数: 90)
#    💡 現在の最高収率: 100.00%
# ------------------------------------------------------------
# 獲得関数値を計算中... (1428個の候補)
# 🎯 選択: ('Brc1ccc2c(c1)OCO2', 'c1ccc(P(c2ccccc2)c2ccccc2)cc1.OB(O)B(O)O.CCO') (EI: 0.7785)
# 🔎 Trial 91: Brc1ccc2c(c1)OCO2 + c1ccc(P(c2ccccc2)c2ccccc2)cc1.OB(O)B(O)O.CCO → OB(O)c1ccc2c(c1)OCO2
#    📈 予測: 64.24% ± 24.44%
#    🧪 真値: 73.24%
#    ❗ 誤差: -9.00%
#    🎯 獲得関数: 0.7785
#    🔄 モデル更新中... (学習データ数: 91)
#    💡 現在の最高収率: 100.00%
# ------------------------------------------------------------
# 獲得関数値を計算中... (1427個の候補)
# 🎯 選択: ('Brc1ccc2c(c1)OCO2', 'c1ccc(P(c2ccccc2)c2ccccc2)cc1.OB(O)B(O)O.CO') (EI: 0.7696)
# 🔎 Trial 92: Brc1ccc2c(c1)OCO2 + c1ccc(P(c2ccccc2)c2ccccc2)cc1.OB(O)B(O)O.CO → OB(O)c1ccc2c(c1)OCO2
#    📈 予測: 64.34% ± 24.33%
#    🧪 真値: 54.09%
#    ❗ 誤差: +10.25%
#    🎯 獲得関数: 0.7696
#    🔄 モデル更新中... (学習データ数: 92)
#    💡 現在の最高収率: 100.00%
# ------------------------------------------------------------
# 獲得関数値を計算中... (1426個の候補)
# 🎯 選択: ('Brc1ccc2occc2c1', 'C1CCC([PH+](C2CCCCC2)C2CCCCC2)CC1.F[B-](F)(F)F.OB(O)B(O)O.CCO') (EI: 0.7470)
# 🔎 Trial 93: Brc1ccc2occc2c1 + C1CCC([PH+](C2CCCCC2)C2CCCCC2)CC1.F[B-](F)(F)F.OB(O)B(O)O.CCO → OB(O)c1ccc2occc2c1
#    📈 予測: 64.23% ± 24.22%
#    🧪 真値: 8.12%
#    ❗ 誤差: +56.11%
#    🎯 獲得関数: 0.7470
#    🔄 モデル更新中... (学習データ数: 93)
#    💡 現在の最高収率: 100.00%
# ------------------------------------------------------------
# 獲得関数値を計算中... (1425個の候補)
# 🎯 選択: ('Brc1ccc2occc2c1', 'C1CCC([PH+](C2CCCCC2)C2CCCCC2)CC1.F[B-](F)(F)F.OB(O)B(O)O.CO') (EI: 0.7795)
# 🔎 Trial 94: Brc1ccc2occc2c1 + C1CCC([PH+](C2CCCCC2)C2CCCCC2)CC1.F[B-](F)(F)F.OB(O)B(O)O.CO → OB(O)c1ccc2occc2c1
#    📈 予測: 63.62% ± 24.77%
#    🧪 真値: 19.05%
#    ❗ 誤差: +44.57%
#    🎯 獲得関数: 0.7795
#    🔄 モデル更新中... (学習データ数: 94)
#    💡 現在の最高収率: 100.00%
# ------------------------------------------------------------
# 獲得関数値を計算中... (1424個の候補)
# 🎯 選択: ('Brc1ccc2occc2c1', 'CC(=C(c1ccccc1)c1ccccc1)P(C1CCCCC1)C1CCCCC1.OB(O)B(O)O.CCO') (EI: 0.7851)
# 🔎 Trial 95: Brc1ccc2occc2c1 + CC(=C(c1ccccc1)c1ccccc1)P(C1CCCCC1)C1CCCCC1.OB(O)B(O)O.CCO → OB(O)c1ccc2occc2c1
#    📈 予測: 63.15% ± 25.06%
#    🧪 真値: 39.42%
#    ❗ 誤差: +23.73%
#    🎯 獲得関数: 0.7851
#    🔄 モデル更新中... (学習データ数: 95)
#    💡 現在の最高収率: 100.00%
# ------------------------------------------------------------
# 獲得関数値を計算中... (1423個の候補)
# 🎯 選択: ('Brc1ccc2occc2c1', 'CC(=C(c1ccccc1)c1ccccc1)P(C1CCCCC1)C1CCCCC1.OB(O)B(O)O.CO') (EI: 0.7657)
# 🔎 Trial 96: Brc1ccc2occc2c1 + CC(=C(c1ccccc1)c1ccccc1)P(C1CCCCC1)C1CCCCC1.OB(O)B(O)O.CO → OB(O)c1ccc2occc2c1
#    📈 予測: 62.90% ± 25.05%
#    🧪 真値: 59.22%
#    ❗ 誤差: +3.68%
#    🎯 獲得関数: 0.7657
#    🔄 モデル更新中... (学習データ数: 96)
#    💡 現在の最高収率: 100.00%
# ------------------------------------------------------------
# 獲得関数値を計算中... (1422個の候補)
# 🎯 選択: ('Brc1ccc2occc2c1', 'CC(C)(C)P(c1ccccc1)C(C)(C)C.OB(O)B(O)O.CCO') (EI: 0.7461)
# 🔎 Trial 97: Brc1ccc2occc2c1 + CC(C)(C)P(c1ccccc1)C(C)(C)C.OB(O)B(O)O.CCO → OB(O)c1ccc2occc2c1
#    📈 予測: 62.86% ± 24.92%
#    🧪 真値: 4.10%
#    ❗ 誤差: +58.76%
#    🎯 獲得関数: 0.7461
#    🔄 モデル更新中... (学習データ数: 97)
#    💡 現在の最高収率: 100.00%
# ------------------------------------------------------------
# 獲得関数値を計算中... (1421個の候補)
# 🎯 選択: ('Brc1ccc2occc2c1', 'CC(C)(C)P(c1ccccc1)C(C)(C)C.OB(O)B(O)O.CO') (EI: 0.7803)
# 🔎 Trial 98: Brc1ccc2occc2c1 + CC(C)(C)P(c1ccccc1)C(C)(C)C.OB(O)B(O)O.CO → OB(O)c1ccc2occc2c1
#    📈 予測: 62.26% ± 25.49%
#    🧪 真値: 6.43%
#    ❗ 誤差: +55.83%
#    🎯 獲得関数: 0.7803
#    🔄 モデル更新中... (学習データ数: 98)
#    💡 現在の最高収率: 100.00%
# ------------------------------------------------------------
# 獲得関数値を計算中... (1420個の候補)
# 🎯 選択: ('Brc1ccc2occc2c1', 'CC(C)c1cc(C(C)C)c(-c2ccccc2P(c2ccccc2)c2ccccc2)c(C(C)C)c1.OB(O)B(O)O.CCO') (EI: 0.8054)
# 🔎 Trial 99: Brc1ccc2occc2c1 + CC(C)c1cc(C(C)C)c(-c2ccccc2P(c2ccccc2)c2ccccc2)c(C(C)C)c1.OB(O)B(O)O.CCO → OB(O)c1ccc2occc2c1
#    📈 予測: 61.69% ± 25.98%
#    🧪 真値: 27.76%
#    ❗ 誤差: +33.93%
#    🎯 獲得関数: 0.8054
#    🔄 モデル更新中... (学習データ数: 99)
#    💡 現在の最高収率: 100.00%
# ------------------------------------------------------------
# 獲得関数値を計算中... (1419個の候補)
# 🎯 選択: ('Brc1ccc2occc2c1', 'CC(C)c1cc(C(C)C)c(-c2ccccc2P(c2ccccc2)c2ccccc2)c(C(C)C)c1.OB(O)B(O)O.CO') (EI: 0.7936)
# 🔎 Trial 100: Brc1ccc2occc2c1 + CC(C)c1cc(C(C)C)c(-c2ccccc2P(c2ccccc2)c2ccccc2)c(C(C)C)c1.OB(O)B(O)O.CO → OB(O)c1ccc2occc2c1
#    📈 予測: 61.34% ± 26.07%
#    🧪 真値: 41.70%
#    ❗ 誤差: +19.64%
#    🎯 獲得関数: 0.7936
#    🔄 モデル更新中... (学習データ数: 100)
#    💡 現在の最高収率: 100.00%
# ------------------------------------------------------------
#
# 最適化完了! 総試行数: 100
# 🏆 最高収率: 100.00%
# 🏆 最適組み合わせ: Brc1ccc(-c2ccccc2)cc1 + Fc1ccc(P(c2ccc(F)cc2)c2ccc(F)cc2)cc1.OB(O)B(O)O.CCO → OB(O)c1ccc(-c2ccccc2)cc1
#
# === 最適化概要 ===
# 総試行数: 100
# 最高収率: 100.00%
# 平均収率: 61.15%
# 収率標準偏差: 25.99%
# 予測誤差 (MAE): 21.78%
# 予測誤差 (RMSE): 26.36%
# 探索範囲: 6.6%
# ログファイル: ../runs/gpr_100trials_NiB/optimization_log.csv
# 可視化完了! 保存先: ../runs/gpr_100trials_NiB/visualization

# %% [markdown]
# ## 可視化

# %%
# 保存された可視化を表示
from IPython.display import Image, display

save_dir = os.path.join(gp_optimizer.output_dir, "visualization")

if os.path.exists(save_dir):
    plot_files = [
        ('optimization_progress.png', 'Optimization Progress'),
        ('parity.png', 'Parity Plot'),
        ('uncertainty.png', 'Prediction Uncertainty'),
        ('error_trend.png', 'Error Trend'),
        ('error_hist.png', 'Error Distribution'),
        ('uncertainty_vs_yield.png', 'Uncertainty vs Actual Yield')
    ]
    
    for filename, title in plot_files:
        filepath = os.path.join(save_dir, filename)
        if os.path.exists(filepath):
            print(f"\n### {title}")
            display(Image(filename=filepath))
else:
    print("可視化ファイルが見つかりません。")
# Out:
# ### Optimization Progress
# ### Parity Plot
# ### Prediction Uncertainty
# ### Error Trend
# ### Error Distribution
# ### Uncertainty vs Actual Yield
